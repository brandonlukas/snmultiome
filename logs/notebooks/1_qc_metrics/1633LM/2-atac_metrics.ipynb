# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys;sys.path.extend(['/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12/site-packages', '/home/brandon/code/pingyin/snmultiome/workflow/rules', '/home/brandon/code/pingyin/snmultiome/workflow', '/home/brandon/miniconda3/envs/snapatac2_env/bin', '/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12', '/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12/lib-dynload', '/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12/site-packages', '/home/brandon/.cache/snakemake/snakemake/source-cache/runtime-cache/tmpl3iz42yn/file/home/brandon/code/pingyin/snmultiome/workflow/rules/../notebooks/1_qc_metrics', '/home/brandon/code/pingyin/snmultiome/workflow/rules/../notebooks/1_qc_metrics']);import pickle;from snakemake import script;script.snakemake = pickle.loads(b'\x80\x04\x95\xb0\x06\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c+results/0_initialization/1633LM/1633LM.h5mu\x94\x8cM/home/brandon/data/pingyin/snmultiome/input/1633LM/outs/atac_fragments.tsv.gz\x94\x8cb/home/brandon/data/pingyin/snmultiome/input/1633LM/outs/filtered_feature_bc_matrix/barcodes.tsv.gz\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\tfragments\x94K\x01N\x86\x94\x8c\x08barcodes\x94K\x02N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x16h\x06\x8c\x0eAttributeGuard\x94\x93\x94)\x81\x94}\x94\x8c\x04name\x94h\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sbh\x10h\x0bh\x12h\x0cub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8c,results/1_qc_metrics/1633LM/1633LM.atac.h5ad\x94a}\x94(h\x0e}\x94h\x14]\x94(h\x16h\x17eh\x16h\x19)\x81\x94}\x94h\x1ch\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sbub\x8c\r_params_store\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94\x8c\x1fresources/hg38-blacklist.v2.bed\x94a}\x94(h\x0e}\x94\x8c\tblacklist\x94K\x00N\x86\x94sh\x14]\x94(h\x16h\x17eh\x16h\x19)\x81\x94}\x94h\x1ch\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sbh2h/ub\x8c\r_params_types\x94}\x94\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\x061633LM\x94a}\x94(h\x0e}\x94\x8c\x06sample\x94K\x00N\x86\x94sh\x14]\x94(h\x16h\x17eh\x16h\x19)\x81\x94}\x94h\x1ch\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sb\x8c\x06sample\x94h?ub\x8c\x07threads\x94K\x0c\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x0cK\x01\x8c\x04/tmp\x94e}\x94(h\x0e}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x14]\x94(h\x16h\x17eh\x16h\x19)\x81\x94}\x94h\x1ch\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sbhRK\x0chTK\x01hVhOub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c7logs/notebooks/1_qc_metrics/1633LM/2-atac_metrics.ipynb\x94a}\x94(h\x0e}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x14]\x94(h\x16h\x17eh\x16h\x19)\x81\x94}\x94h\x1ch\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sbhdhaub\x8c\x06config\x94}\x94(\x8c\x08data_dir\x94\x8c,/home/brandon/data/pingyin/snmultiome/input/\x94\x8c\x0bresults_dir\x94\x8c\x08results/\x94\x8c\x07samples\x94]\x94(\x8c\x061619LM\x94\x8c\x061619MM\x94\x8c\x061633LM\x94\x8c\r1633MM-repeat\x94e\x8c\x03RNA\x94}\x94(\x8c\x10celltypist_model\x94\x8c\x1bHuman_Endometrium_Atlas.pkl\x94\x8c\x02qc\x94}\x94(\x8c\tmin_genes\x94K\xc8\x8c\nmin_counts\x94M\xf4\x01\x8c\rpct_counts_mt\x94K\x05\x8c\x0fpct_counts_ribo\x94K\x05\x8c\rdoublet_score\x94G?\xd3333333\x8c\tmin_cells\x94K\x03uu\x8c\x04ATAC\x94}\x94(\x8c\tblacklist\x94h/\x8c\x02qc\x94}\x94(\x8c\x08min_tsse\x94K\x07\x8c\nmin_counts\x94M\xe8\x03\x8c\tmin_cells\x94K\x03uuu\x8c\x04rule\x94\x8c\x0catac_metrics\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cN/home/brandon/code/pingyin/snmultiome/workflow/rules/../notebooks/1_qc_metrics\x94ub.');del script;from snakemake.logging import logger;from snakemake.script import snakemake;import os; os.chdir(r'/home/brandon/code/pingyin/snmultiome');
######## snakemake preamble end #########

# %% [markdown]
# # Compute ATAC QC metrics

# %%
# Load libraries
import snapatac2 as snap
import pandas as pd
from snakemake.script import snakemake

# %%
# Read input and output paths from Snakemake
fragment_file = snakemake.input["fragments"]
barcodes_file = snakemake.input["barcodes"]
output_file = snakemake.output[0]
n_jobs = snakemake.threads
blacklist_file = snakemake.params.get("blacklist", None)

# %%
# Extract list of barcodes
whitelist = pd.read_csv(barcodes_file, header=None)[0].tolist()
whitelist
# Out:
# ['AAACAGCCAAACTGTT-1',
#  'AAACAGCCAAAGCGCA-1',
#  'AAACAGCCAATAACCT-1',
#  'AAACAGCCAATATAGG-1',
#  'AAACAGCCAGCTCATA-1',
#  'AAACAGCCAGGTCCTG-1',
#  'AAACATGCAAGCCACT-1',
#  'AAACATGCAAGCGAGC-1',
#  'AAACATGCAAGGACCA-1',
#  'AAACATGCACGGTACT-1',
#  'AAACATGCAGCGCTTG-1',
#  'AAACCAACAAACGCGA-1',
#  'AAACCAACAATTGAGA-1',
#  'AAACCAACACAGACTC-1',
#  'AAACCAACACCTGTAA-1',
#  'AAACCAACAGGCTAGA-1',
#  'AAACCAACATTGTCCT-1',
#  'AAACCGAAGCACCACA-1',
#  'AAACCGAAGCCGCAGT-1',
#  'AAACCGAAGGTGCGGA-1',
#  'AAACCGAAGTGTTGCG-1',
#  'AAACCGCGTTGAATCG-1',
#  'AAACCGCGTTGCAGTA-1',
#  'AAACCGCGTTGTTGTC-1',
#  'AAACCGGCAAACCTTG-1',
#  'AAACCGGCACAATTAC-1',
#  'AAACCGGCACTCGCTC-1',
#  'AAACCGGCACTGGCCA-1',
#  'AAACCGGCAGAAACGT-1',
#  'AAACCGGCAGCTCATA-1',
#  'AAACCGGCAGCTTAAT-1',
#  'AAACGCGCAAATGCCC-1',
#  'AAACGCGCAATGCCTA-1',
#  'AAACGCGCACCAGGTT-1',
#  'AAACGCGCACGGTACT-1',
#  'AAACGCGCATCAGTAT-1',
#  'AAACGCGCATCCCGCT-1',
#  'AAACGGATCGCACACA-1',
#  'AAACGTACAAACGCGA-1',
#  'AAACGTACAAGTGTTT-1',
#  'AAACGTACACTTACAG-1',
#  'AAACGTACAGAGAGCC-1',
#  'AAACGTACAGGCTGTT-1',
#  'AAACGTACATTAAACC-1',
#  'AAAGCAAGTACCGAAC-1',
#  'AAAGCAAGTACCTTAC-1',
#  'AAAGCAAGTGCTCACC-1',
#  'AAAGCAAGTGTAACCA-1',
#  'AAAGCAAGTTTACTTG-1',
#  'AAAGCACCAAGGAATC-1',
#  'AAAGCACCACAAAGGT-1',
#  'AAAGCACCACATAGCC-1',
#  'AAAGCACCAGGAATCG-1',
#  'AAAGCACCAGGATGGC-1',
#  'AAAGCACCATTAAACC-1',
#  'AAAGCCCGTACGGTAC-1',
#  'AAAGCCCGTGAAGCCT-1',
#  'AAAGCCCGTGTAACCA-1',
#  'AAAGCCCGTTTGACCT-1',
#  'AAAGCCGCAATATACC-1',
#  'AAAGCCGCACCTGGTG-1',
#  'AAAGCCGCATGTTGTG-1',
#  'AAAGCGGGTAATAGCT-1',
#  'AAAGCGGGTAATCGGC-1',
#  'AAAGCGGGTCAAGTAT-1',
#  'AAAGCGGGTCCTAAGA-1',
#  'AAAGCTTGTCAAAGAA-1',
#  'AAAGCTTGTCCTTAGT-1',
#  'AAAGGACGTACTTAGG-1',
#  'AAAGGACGTCAAGACC-1',
#  'AAAGGACGTGAAACAA-1',
#  'AAAGGACGTGAGACTC-1',
#  'AAAGGACGTGGACATC-1',
#  'AAAGGACGTTATTGCC-1',
#  'AAAGGAGCACGTAAGG-1',
#  'AAAGGCTCAACCTAAT-1',
#  'AAAGGCTCAATAAGCA-1',
#  'AAAGGCTCAATTGAAG-1',
#  'AAAGGCTCACAAACTT-1',
#  'AAAGGCTCAGCAAGGC-1',
#  'AAAGGCTCATAACGGG-1',
#  'AAAGGTTAGACAGGCG-1',
#  'AAAGGTTAGCTCGCTT-1',
#  'AAAGGTTAGGGTCCAC-1',
#  'AAAGGTTAGGTCTTGG-1',
#  'AAAGGTTAGGTGCGGA-1',
#  'AAAGGTTAGTTAGACC-1',
#  'AAATCCGGTAAGCTTG-1',
#  'AAATCCGGTGCAATGC-1',
#  'AAATCCGGTTAACGGC-1',
#  'AAATCCGGTTGCTTCG-1',
#  'AAATCCGGTTTAGTCC-1',
#  'AAATGCCTCACGTTAA-1',
#  'AAATGCCTCATTGCAA-1',
#  'AAATGCCTCTAAGGAG-1',
#  'AAATGCCTCTTAAGTG-1',
#  'AAATGGCCACAATTAC-1',
#  'AAATGGCCACATTAAC-1',
#  'AAATGGCCAGCAACCT-1',
#  'AAATGGCCAGTTTCTC-1',
#  'AACAAAGGTAATCACG-1',
#  'AACAAAGGTACGCGCA-1',
#  'AACAAAGGTATTGAGT-1',
#  'AACAAAGGTCATAACG-1',
#  'AACAAAGGTTAAGCGC-1',
#  'AACAAAGGTTGCCTCA-1',
#  'AACAAGCCAAACTCAT-1',
#  'AACAAGCCAATATACC-1',
#  'AACAAGCCACCTAATG-1',
#  'AACAAGCCATAAGTCT-1',
#  'AACAGATAGGACTTAC-1',
#  'AACAGATAGTAGCTTA-1',
#  'AACAGATAGTCAATCA-1',
#  'AACAGATAGTCAATTG-1',
#  'AACAGATAGTTGCGTG-1',
#  'AACAGCAAGACAAGTG-1',
#  'AACAGCAAGGAGGCAT-1',
#  'AACAGCAAGGGTTATC-1',
#  'AACAGCAAGTAGCGGG-1',
#  'AACAGGATCAATTGGC-1',
#  'AACAGGATCAGGGCCT-1',
#  'AACAGGATCGAGGTGG-1',
#  'AACAGGATCTAATCTC-1',
#  'AACATAGCAAACCTTG-1',
#  'AACATAGCAAATACCT-1',
#  'AACATAGCACTGGCCA-1',
#  'AACATAGCAGGTTACC-1',
#  'AACATAGCAGTAGCCT-1',
#  'AACATAGCAGTAGGAT-1',
#  'AACATCATCATGTGGT-1',
#  'AACATCATCCAGGTCA-1',
#  'AACATCATCCCGTTAC-1',
#  'AACATCATCCTAGTTT-1',
#  'AACATTGTCCAGGGAG-1',
#  'AACATTGTCCAGGTTG-1',
#  'AACCCGCAGAGAAGGG-1',
#  'AACCCGCAGCATGTCG-1',
#  'AACCCGCAGCTGGACC-1',
#  'AACCCGCAGGTGTTAC-1',
#  'AACCCGCAGTCTGGGC-1',
#  'AACCGCTCAACCTGGT-1',
#  'AACCGCTCACTGGCCA-1',
#  'AACCGCTCAGTCTATG-1',
#  'AACCGCTCATCAGCAC-1',
#  'AACCGCTCATGAATCT-1',
#  'AACCGCTCATGAGTTT-1',
#  'AACCGGCTCAATTACG-1',
#  'AACCGGCTCATCCTAT-1',
#  'AACCGGCTCCACCTTA-1',
#  'AACCGGCTCGACCTGA-1',
#  'AACCGGCTCGTTAGTA-1',
#  'AACCGGCTCTCGCCCA-1',
#  'AACCGGCTCTGTTGCC-1',
#  'AACCTAATCAATACGC-1',
#  'AACCTAATCACTTCAT-1',
#  'AACCTAATCCTTCTAG-1',
#  'AACCTAATCGCAAACT-1',
#  'AACCTAATCGCACACA-1',
#  'AACCTAATCGCTTCTA-1',
#  'AACCTCACAAACGCGA-1',
#  'AACCTCACAACCGCCA-1',
#  'AACCTCACAATAAGCA-1',
#  'AACCTCACACATAGCC-1',
#  'AACCTCACAGCCGCTA-1',
#  'AACCTCACAGGCAAGC-1',
#  'AACCTCACAGTACCGT-1',
#  'AACCTCACATGAATAG-1',
#  'AACCTCCTCAATCATG-1',
#  'AACCTCCTCACCTGCT-1',
#  'AACCTCCTCCAAGTGT-1',
#  'AACCTCCTCCCTTGCG-1',
#  'AACCTCCTCCTAAGGT-1',
#  'AACCTCCTCGCCTGTT-1',
#  'AACCTTGCAAGGTATA-1',
#  'AACCTTGCAAGGTGGC-1',
#  'AACCTTGCAATGAAGC-1',
#  'AACCTTGCAGGACCTT-1',
#  'AACCTTGCAGTACCGT-1',
#  'AACCTTGCAGTTATCG-1',
#  'AACCTTGCATAAGCAA-1',
#  'AACCTTGCATGCTATG-1',
#  'AACGACAAGACTCGCA-1',
#  'AACGACAAGGAGCACG-1',
#  'AACGACAAGGCTGGCT-1',
#  'AACGACAAGGGCCATC-1',
#  'AACGACAAGTACCGCA-1',
#  'AACGACAAGTCTCACC-1',
#  'AACGACAAGTTAGCTA-1',
#  'AACGCCCAGGAAGCAC-1',
#  'AACGCCCAGGAAGCTA-1',
#  'AACGCCCAGGCATTAC-1',
#  'AACGCCCAGTGTTGCG-1',
#  'AACGCTAGTACGGGTT-1',
#  'AACGCTAGTAGCTGCG-1',
#  'AACGCTAGTCCTAACT-1',
#  'AACGCTAGTTATCCTA-1',
#  'AACGCTAGTTGGATCA-1',
#  'AACGCTAGTTGTCATC-1',
#  'AACGGTAAGACTTATG-1',
#  'AACGGTAAGCATGACT-1',
#  'AACGGTAAGCGCTCAA-1',
#  'AACGGTAAGGGTCCAC-1',
#  'AACGGTAAGTAGAGGC-1',
#  'AACTACTCAAGTGTTT-1',
#  'AACTACTCAGTTGCGT-1',
#  'AACTACTCATAAGTTC-1',
#  'AACTACTCATAGACCC-1',
#  'AACTAGCTCAAACACC-1',
#  'AACTAGCTCATGGCCA-1',
#  'AACTAGCTCCTCAGTC-1',
#  'AACTAGCTCCTGAATA-1',
#  'AACTAGCTCGCGACAC-1',
#  'AACTAGCTCTAATCAG-1',
#  'AACTAGCTCTAGCGAT-1',
#  'AACTAGCTCTCACTAT-1',
#  'AACTAGCTCTGTTGCC-1',
#  'AACTAGTGTAGGTGTC-1',
#  'AACTAGTGTGAGACTC-1',
#  'AACTAGTGTGCTTAGA-1',
#  'AACTAGTGTTACTTGC-1',
#  'AACTCACAGGTCTTGG-1',
#  'AACTCACAGTCCTTTG-1',
#  'AACTGTTCAAGCTTTG-1',
#  'AACTGTTCAATATACC-1',
#  'AACTGTTCAGCACCAT-1',
#  'AACTGTTCAGGAATCG-1',
#  'AACTTAGTCATGCAAC-1',
#  'AACTTAGTCATTAGCA-1',
#  'AACTTAGTCGATCAGT-1',
#  'AACTTAGTCGCTATAA-1',
#  'AACTTAGTCTAACCAA-1',
#  'AACTTAGTCTCATCAT-1',
#  'AAGAACAGTATTTGGG-1',
#  'AAGAACAGTCGCAAAC-1',
#  'AAGAACAGTGCATTAG-1',
#  'AAGAACAGTTGGATAT-1',
#  'AAGAATCAGACAAAGT-1',
#  'AAGAATCAGCAGCTCA-1',
#  'AAGAATCAGCGGATAA-1',
#  'AAGAATCAGGCCATCA-1',
#  'AAGAATCAGGTCCTGA-1',
#  'AAGAATCAGTTAACCA-1',
#  'AAGAATCAGTTATGGC-1',
#  'AAGACAAGTCAATACG-1',
#  'AAGACAAGTGATGATT-1',
#  'AAGACAAGTTAATGCG-1',
#  'AAGACAAGTTATCCGT-1',
#  'AAGACAAGTTGCACAA-1',
#  'AAGACAAGTTGGATAT-1',
#  'AAGACAAGTTTAGCGA-1',
#  'AAGACATAGCACTAGT-1',
#  'AAGACATAGCATGTTA-1',
#  'AAGACATAGCGAGCGA-1',
#  'AAGACATAGGTCCACA-1',
#  'AAGACATAGTAATCCA-1',
#  'AAGACATAGTCACTAA-1',
#  'AAGACATAGTTGGCCA-1',
#  'AAGACCAAGAAACTGG-1',
#  'AAGACCAAGACACCGC-1',
#  'AAGACCAAGCATGAAG-1',
#  'AAGACCAAGCCTCTCG-1',
#  'AAGACCAAGGAAACTG-1',
#  'AAGACCAAGGGTCTAT-1',
#  'AAGACCAAGTTATGTG-1',
#  'AAGCAAGTCAACAAGG-1',
#  'AAGCAAGTCAGGCTAT-1',
#  'AAGCAAGTCAGTTCCC-1',
#  'AAGCAAGTCCTAGTAA-1',
#  'AAGCAAGTCCTGATGG-1',
#  'AAGCAAGTCGTAATCA-1',
#  'AAGCAAGTCTAGCTTT-1',
#  'AAGCATGAGCGGATAA-1',
#  'AAGCATGAGCTTGCTC-1',
#  'AAGCATGAGTTTGCGG-1',
#  'AAGCCACGTACCAGGT-1',
#  'AAGCCACGTCAGGAAG-1',
#  'AAGCCACGTCGCGCAA-1',
#  'AAGCCACGTCTTTATG-1',
#  'AAGCCACGTGTGTGGT-1',
#  'AAGCCACGTTAGGACC-1',
#  'AAGCCTCCAAGGTGGC-1',
#  'AAGCCTCCAATACTGT-1',
#  'AAGCCTCCACGAATTT-1',
#  'AAGCCTCCATGAGTTT-1',
#  'AAGCCTCCATTATGCG-1',
#  'AAGCCTGTCCCGCCTA-1',
#  'AAGCCTGTCGTAATCA-1',
#  'AAGCCTGTCTCACACC-1',
#  'AAGCCTGTCTTGATGA-1',
#  'AAGCCTTAGAGAGGAG-1',
#  'AAGCCTTAGATGGAGC-1',
#  'AAGCCTTAGCATTTCT-1',
#  'AAGCCTTAGTAGGATG-1',
#  'AAGCCTTAGTGAGCAA-1',
#  'AAGCGAATCAGCCAAT-1',
#  'AAGCGAATCAGGCTAT-1',
#  'AAGCGAATCCTGTTCA-1',
#  'AAGCGAATCGATTTAG-1',
#  'AAGCGAATCGATTTGA-1',
#  'AAGCGAATCTAGCTAA-1',
#  'AAGCGAGGTCAGGCAT-1',
#  'AAGCGAGGTGCACGCA-1',
#  'AAGCGCTGTAAATTGC-1',
#  'AAGCGCTGTAAGTCGC-1',
#  'AAGCGCTGTAGCCATA-1',
#  'AAGCGCTGTAGGTGTC-1',
#  'AAGCGCTGTATTGTCC-1',
#  'AAGCGCTGTCCGTAGG-1',
#  'AAGCGCTGTGCTCCAC-1',
#  'AAGCGCTGTTTGTCTA-1',
#  'AAGCGGGTCAGCAAGA-1',
#  'AAGCGGGTCATCGTTT-1',
#  'AAGCGGGTCGTTACTT-1',
#  'AAGCGGGTCTCCATAT-1',
#  'AAGCGTTTCAATGTGC-1',
#  'AAGCGTTTCAGGTTTA-1',
#  'AAGCGTTTCATAACTG-1',
#  'AAGCGTTTCCCTCATA-1',
#  'AAGCGTTTCCTTCGTA-1',
#  'AAGCGTTTCGCAGGCT-1',
#  'AAGCGTTTCGGGACCT-1',
#  'AAGCGTTTCTCAATTC-1',
#  'AAGCGTTTCTCCTCTT-1',
#  'AAGCGTTTCTGCAAGT-1',
#  'AAGCGTTTCTTAGCCC-1',
#  'AAGCGTTTCTTTGAGA-1',
#  'AAGCTAGAGCTTAACA-1',
#  'AAGCTATGTCCAAGAC-1',
#  'AAGCTATGTGTGTCCC-1',
#  'AAGCTATGTTAAGTGT-1',
#  'AAGCTATGTTAGACCA-1',
#  'AAGCTCCCAAACCTAT-1',
#  'AAGCTCCCACAGCCAT-1',
#  'AAGCTCCCAGTTTACG-1',
#  'AAGCTTGGTCCTTTAA-1',
#  'AAGCTTGGTGAGACTC-1',
#  'AAGGAAGCACTTACAG-1',
#  'AAGGATCCAATGAGGT-1',
#  'AAGGATCCACAGAACG-1',
#  'AAGGATCCACATGCTA-1',
#  'AAGGATCCAGGCTAAG-1',
#  'AAGGATCCATGACTAT-1',
#  'AAGGATGTCAAGTGAG-1',
#  'AAGGATGTCATTTGTC-1',
#  'AAGGATTAGATAACCC-1',
#  'AAGGATTAGCATGAAG-1',
#  'AAGGATTAGCTGGACC-1',
#  'AAGGATTAGGATAAAC-1',
#  'AAGGCCCTCAAACACC-1',
#  'AAGGCCCTCGTTTCTG-1',
#  'AAGGCCCTCTAATCTC-1',
#  'AAGGTATAGACCATAC-1',
#  'AAGGTATAGCAGGCCT-1',
#  'AAGGTATAGCATCCAG-1',
#  'AAGGTATAGGCGCTTA-1',
#  'AAGGTATAGGTTTGAC-1',
#  'AAGGTATAGTTGCGTG-1',
#  'AAGGTCAAGGAACACA-1',
#  'AAGGTCAAGGCAAGTA-1',
#  'AAGGTCAAGGCTAATC-1',
#  'AAGGTCAAGTCTATGA-1',
#  'AAGGTCAAGTGACCTG-1',
#  'AAGGTGCAGCACCACA-1',
#  'AAGGTGCAGCCTCTCG-1',
#  'AAGGTGCAGTTAGTTG-1',
#  'AAGGTGCAGTTATGGC-1',
#  'AAGGTGCAGTTATTCC-1',
#  'AAGGTGCAGTTTGAGC-1',
#  'AAGGTGCAGTTTGTCT-1',
#  'AAGTAGCCAAGGTGGC-1',
#  'AAGTAGCCACCTGTAA-1',
#  'AAGTAGCCATTAGGTT-1',
#  'AAGTAGCCATTGTTGG-1',
#  'AAGTCTATCAAACCGT-1',
#  'AAGTCTATCATAGCCG-1',
#  'AAGTCTATCCAGGTTG-1',
#  'AAGTCTATCGTTAGTA-1',
#  'AAGTCTATCTCGCCTG-1',
#  'AAGTGAAGTTCCAGGG-1',
#  'AAGTGAAGTTTCAGGA-1',
#  'AAGTGAAGTTTCGCCA-1',
#  'AAGTGCAAGATAGACG-1',
#  'AAGTGCAAGCGATAAG-1',
#  'AAGTGCAAGGTCCGTA-1',
#  'AAGTGCAAGGTGCGGA-1',
#  'AAGTGCAAGTGAGCAA-1',
#  'AAGTGCAAGTTATTCC-1',
#  'AAGTGCAAGTTTGAGC-1',
#  'AAGTGTTGTAAACAAG-1',
#  'AAGTGTTGTCATGCAA-1',
#  'AAGTGTTGTGTTCCCA-1',
#  'AAGTTACGTCAATGTG-1',
#  'AAGTTACGTCCTAATC-1',
#  'AAGTTACGTGATTACG-1',
#  'AAGTTACGTTGCCTCA-1',
#  'AAGTTAGCAACCTGGT-1',
#  'AAGTTAGCAAGGAATC-1',
#  'AAGTTAGCAATCCCTT-1',
#  'AAGTTAGCACCAGGTT-1',
#  'AAGTTAGCAGGCATGA-1',
#  'AAGTTAGCATCCTAGA-1',
#  'AAGTTTGTCATGTCAA-1',
#  'AAGTTTGTCCGCCAAA-1',
#  'AAGTTTGTCCTAGTAA-1',
#  'AATAACCGTCAGGAAG-1',
#  'AATAACCGTCTCACTG-1',
#  'AATAACCGTGTCACGG-1',
#  'AATAACCGTTGCACAA-1',
#  'AATACCGGTACCGGAT-1',
#  'AATACCGGTGCGCGTA-1',
#  'AATACCGGTTAAGCGC-1',
#  'AATAGAGGTAACGTGC-1',
#  'AATAGAGGTCATTGAG-1',
#  'AATAGAGGTTGAAGCC-1',
#  'AATAGCTGTAATCGCA-1',
#  'AATAGCTGTAGGTTGC-1',
#  'AATAGCTGTATACTGG-1',
#  'AATAGCTGTCTATCGT-1',
#  'AATATCCCAAAGGCCA-1',
#  'AATATCCCAGGTTATT-1',
#  'AATATCCCAGTAAAGC-1',
#  'AATATCCCAGTTATGT-1',
#  'AATATCCCATCAGTAT-1',
#  'AATCAGGAGCGAGGTG-1',
#  'AATCAGGAGGATAAAC-1',
#  'AATCAGGAGGCGCTAC-1',
#  'AATCAGGAGGCGGGTA-1',
#  'AATCAGGAGGGACCTC-1',
#  'AATCAGGAGTAACCAC-1',
#  'AATCATCCAAACCCTA-1',
#  'AATCATCCAACTGGGA-1',
#  'AATCATCCACACTAAT-1',
#  'AATCATCCAGGAACTG-1',
#  'AATCATCCATGAAATG-1',
#  'AATCATCCATTAGGCC-1',
#  'AATCATGTCCTAATTC-1',
#  'AATCATGTCGAGGTGG-1',
#  'AATCATGTCTTGCAGG-1',
#  'AATCCATCAGCAACAG-1',
#  'AATCCATCAGGAACAT-1',
#  'AATCCATCAGGTTAAA-1',
#  'AATCCATCATCACTTC-1',
#  'AATCCATCATGGTTAT-1',
#  'AATCCATCATTGTCAG-1',
#  'AATCCCTGTAGCAGCT-1',
#  'AATCCCTGTCCAAGAC-1',
#  'AATCCCTGTCCTTCTC-1',
#  'AATCCCTGTCTTGCAT-1',
#  'AATCCCTGTTTCGCCA-1',
#  'AATCCCTGTTTGGGCG-1',
#  'AATCCGTAGGACCTGC-1',
#  'AATCCGTAGTAAAGGT-1',
#  'AATCCGTAGTCAATTG-1',
#  'AATCCTAAGAAAGGAA-1',
#  'AATCCTAAGCCACATG-1',
#  'AATCCTAAGCTGGAAA-1',
#  'AATCCTAAGGAGGGTT-1',
#  'AATCCTAAGGAGTAAT-1',
#  'AATCGCCCAACCTGGT-1',
#  'AATCGCCCAAGCTTTG-1',
#  'AATCGCCCACTCAACA-1',
#  'AATCTCAAGAAAGCAT-1',
#  'AATCTCAAGGCCTAAT-1',
#  'AATCTCAAGTTATCTC-1',
#  'AATCTCAAGTTGTCCC-1',
#  'AATCTCAAGTTTGTCT-1',
#  'AATCTTGAGCTCAATA-1',
#  'AATCTTGAGTCTTGAA-1',
#  'AATCTTGAGTGAACCT-1',
#  'AATCTTGAGTTAGAGG-1',
#  'AATCTTGAGTTGCGTG-1',
#  'AATGAAGGTGTCCTGC-1',
#  'AATGAAGGTTAAATGC-1',
#  'AATGAAGGTTATCGAG-1',
#  'AATGCAACAAGGTATA-1',
#  'AATGCAACAATTAGCT-1',
#  'AATGCAACACTTCACT-1',
#  'AATGCAACAGCCTAAC-1',
#  'AATGCAACATAGGCGA-1',
#  'AATGCAACATTAAGCT-1',
#  'AATGCATGTAGCCTCC-1',
#  'AATGCATGTAGCTGCG-1',
#  'AATGCATGTCAGGAAG-1',
#  'AATGCATGTGTAACCA-1',
#  'AATGCATGTTTAACCC-1',
#  'AATGCATGTTTGAGGC-1',
#  'AATGCGCGTAATCGTG-1',
#  'AATGCGCGTCATCATC-1',
#  'AATGCGCGTGATGAAA-1',
#  'AATGCGCGTTGGATAT-1',
#  'AATGGCGCAAACTCAT-1',
#  'AATGGCGCAACCTGGT-1',
#  'AATGGCGCATAGCTGC-1',
#  'AATGGCGCATTGTGTG-1',
#  'AATGTCATCAAACACC-1',
#  'AATGTCATCAAACCGT-1',
#  'AATGTCATCAATAGCC-1',
#  'AATGTCATCATGCATA-1',
#  'AATGTCATCCTAAGTA-1',
#  'AATGTCATCGTTATAG-1',
#  'AATGTCATCTGGCATG-1',
#  'AATGTCCAGATACTTG-1',
#  'AATGTCCAGGCATGAA-1',
#  'AATGTCCAGTAACTCA-1',
#  'AATGTCCAGTAGCGCC-1',
#  'AATGTCCAGTGAGCGG-1',
#  'AATTACCCAAGGTATA-1',
#  'AATTACCCAAGTGTCC-1',
#  'AATTACCCACGGTTTA-1',
#  'AATTACCCACTGGCCA-1',
#  'AATTACCCATAAAGCA-1',
#  'AATTAGCGTAACTACG-1',
#  'AATTAGCGTACTTAGG-1',
#  'AATTAGCGTCACAAAT-1',
#  'AATTAGCGTGCGCAAT-1',
#  'AATTAGCGTTCCGCAC-1',
#  'AATTAGCGTTTCGCGC-1',
#  'AATTAGGCAAACATAG-1',
#  'AATTAGGCAAGCGAGC-1',
#  'AATTAGGCAATCCTAG-1',
#  'AATTAGGCAATTGACT-1',
#  'AATTAGGCAATTTGGT-1',
#  'AATTAGGCACATTAAC-1',
#  'AATTAGGCACCGGTAT-1',
#  'AATTAGGCAGAGGCTA-1',
#  'AATTCGTCAAGGTACG-1',
#  'AATTCGTCACAAAGAC-1',
#  'AATTCGTCAGGTCCTG-1',
#  'AATTCGTCATCCCGCT-1',
#  'AATTGACGTAGGTGTC-1',
#  'AATTGACGTATTGGTG-1',
#  'AATTGACGTGAAGCCT-1',
#  'AATTGACGTGGATGTC-1',
#  'AATTGACGTTACGCGG-1',
#  'AATTGACGTTAGGCTA-1',
#  'AATTGACGTTCATCTA-1',
#  'AATTGACGTTTCCTCC-1',
#  'AATTGCCAGCGCTCAA-1',
#  'AATTGCCAGTGTTGCG-1',
#  'AATTGCCAGTTTGGGT-1',
#  'AATTGCTCAACAGCCT-1',
#  'AATTGCTCAGGTTTGC-1',
#  'AATTGCTCATCCTGAA-1',
#  'AATTGGACAATAGCCC-1',
#  'AATTGGACAGCAAGGC-1',
#  'AATTGGACAGGATTAA-1',
#  'AATTGGACAGGCGATA-1',
#  'AATTGGACAGGTTAAA-1',
#  'AATTGGACATCCATCT-1',
#  'AATTGGGAGCCTAATA-1',
#  'AATTGGGAGCGAAGTA-1',
#  'AATTGGGAGTCACGAT-1',
#  'AATTGTGTCAATTGGC-1',
#  'AATTGTGTCCTAACGG-1',
#  'AATTGTGTCGCAGGCT-1',
#  'AATTGTGTCGTCCTTA-1',
#  'AATTGTGTCTAGCGTG-1',
#  'AATTTCCTCATGCGTG-1',
#  'AATTTCCTCATTACAG-1',
#  'AATTTGCCAATTAGGA-1',
#  'AATTTGCCACGAACAG-1',
#  'AATTTGCCAGAACCGA-1',
#  'AATTTGCCAGCACGTT-1',
#  'AATTTGCCAGCCTAAC-1',
#  'AATTTGCCAGTCTAGC-1',
#  'AATTTGCCAGTCTATG-1',
#  'AATTTGCCAGTTTACG-1',
#  'AATTTGGTCAAGCTAC-1',
#  'AATTTGGTCCTTGTTG-1',
#  'ACAAACTGTAATCGCA-1',
#  'ACAAACTGTCAATAGT-1',
#  'ACAAACTGTCAATGTG-1',
#  'ACAAAGGTCCGGTATG-1',
#  'ACAAAGGTCGATAACC-1',
#  'ACAAAGGTCGGTTTGG-1',
#  'ACAAAGGTCGTAACGT-1',
#  'ACAAAGGTCTCACTAT-1',
#  'ACAACAACACAACAAA-1',
#  'ACAACAACACCTGTAA-1',
#  'ACAACAACAGGACACA-1',
#  'ACAACAACAGTTTCTC-1',
#  'ACAACAACATTGTCAG-1',
#  'ACAACACTCAATGTCA-1',
#  'ACAACACTCGGTACGC-1',
#  'ACAACAGAGAATCGCT-1',
#  'ACAACAGAGAGCCGGA-1',
#  'ACAACAGAGCACTAGT-1',
#  'ACAACAGAGCATCCAG-1',
#  'ACAACAGAGGAATAAC-1',
#  'ACAACAGAGGATTGAG-1',
#  'ACAACAGAGGCTGGCT-1',
#  'ACAACAGAGGTTACAC-1',
#  'ACAACATGTAAGCACC-1',
#  'ACAACATGTTAGGTGC-1',
#  'ACACAATGTAAGCTCA-1',
#  'ACACAATGTCGCAATA-1',
#  'ACACAATGTGATGAGG-1',
#  'ACACCTTGTCGCATAA-1',
#  'ACACCTTGTTAGCCAA-1',
#  'ACACCTTGTTGAAGCC-1',
#  'ACACGGACACCAGCAT-1',
#  'ACACGGACAGCCTAAC-1',
#  'ACACGGACAGTGAACG-1',
#  'ACACGGACATCCATCT-1',
#  'ACACGGACATGTGGGA-1',
#  'ACACGGACATGTTGGC-1',
#  'ACACTAATCATAACTG-1',
#  'ACACTAATCGGGCCAT-1',
#  'ACACTAATCTCAATAG-1',
#  'ACACTAGGTACCGTTT-1',
#  'ACACTAGGTTAAGCTG-1',
#  'ACACTTAAGACTTACA-1',
#  'ACACTTAAGCCGCTAA-1',
#  'ACACTTAAGCTATTGA-1',
#  'ACACTTAAGTCCTTCA-1',
#  'ACACTTAAGTCTGGGC-1',
#  'ACACTTGCAGAGAGCC-1',
#  'ACACTTGCAGGAACCA-1',
#  'ACAGCCGGTAACAGGG-1',
#  'ACAGCCGGTACGTTTC-1',
#  'ACAGCCGGTCTTTATG-1',
#  'ACAGCCGGTGCCGCAA-1',
#  'ACAGCCGGTTTACCGT-1',
#  'ACAGCGCTCACACAGT-1',
#  'ACAGCGCTCAGGCCTA-1',
#  'ACAGCGCTCATCCTAT-1',
#  'ACAGCGCTCCCTCTAA-1',
#  'ACAGCGCTCCCTTGCG-1',
#  'ACAGCGCTCCGGGACT-1',
#  'ACAGCGCTCTAATTGG-1',
#  'ACAGGAATCAAGTGTC-1',
#  'ACAGGAATCACAGACT-1',
#  'ACAGGAATCACGCCAA-1',
#  'ACAGGAATCATTAGTG-1',
#  'ACAGGAATCCTAGTCC-1',
#  'ACAGGAATCGCCTGTT-1',
#  'ACAGGAATCGGTCAAT-1',
#  'ACAGGAATCTCACTCA-1',
#  'ACAGGATCAAGTAAGC-1',
#  'ACAGGATCAATAATGG-1',
#  'ACAGGATCACAGGATG-1',
#  'ACAGGATCACTCGCTC-1',
#  'ACAGGATCAGCAGGTA-1',
#  'ACAGGATCAGCATGTC-1',
#  'ACAGGATCAGTAAAGC-1',
#  'ACAGGATCATCCTGAA-1',
#  'ACAGGATCATGCTCCC-1',
#  'ACAGGATCATGTCGCG-1',
#  'ACAGGATCATTGCAGC-1',
#  'ACAGGATCATTTGCTC-1',
#  'ACAGGCTGTACCGAAC-1',
#  'ACAGGCTGTACCGGAT-1',
#  'ACAGGCTGTTGAGCCG-1',
#  'ACAGGCTGTTTACTTG-1',
#  'ACAGGCTGTTTGCTGT-1',
#  'ACAGGTAAGAGCCGGA-1',
#  'ACAGGTAAGCAACATC-1',
#  'ACAGGTAAGCCTGTTC-1',
#  'ACAGGTAAGGCATTAC-1',
#  'ACAGTATGTCAAGTAT-1',
#  'ACAGTATGTCTTGCTG-1',
#  'ACAGTATGTTAGAGGG-1',
#  'ACAGTATGTTCCGGGA-1',
#  'ACAGTATGTTGTTGTC-1',
#  'ACATAGCTCAATGTCA-1',
#  'ACATAGCTCATTAGGC-1',
#  'ACATAGCTCGCTTCTA-1',
#  'ACATAGCTCGTCAAGT-1',
#  'ACATAGCTCTTAATGG-1',
#  'ACATAGCTCTTGAGCG-1',
#  'ACATCAATCACAGCGC-1',
#  'ACATCAATCACCATTT-1',
#  'ACATCAATCATCAGTA-1',
#  'ACATCAATCTTGCAGG-1',
#  'ACATCATCAAACTGTT-1',
#  'ACATCATCACCCACCT-1',
#  'ACATCATCACCTACGG-1',
#  'ACATCATCATCACAGC-1',
#  'ACATTAGTCATTTGCT-1',
#  'ACATTAGTCCCTCAGT-1',
#  'ACATTAGTCCGGTTGA-1',
#  'ACATTAGTCCTCATGC-1',
#  'ACATTAGTCGTTCACC-1',
#  'ACATTAGTCTCACATT-1',
#  'ACATTGCAGCACGATT-1',
#  'ACATTGCAGGAAGCTA-1',
#  'ACATTGCAGGCATTGT-1',
#  'ACATTGCAGGGTCCAC-1',
#  'ACATTGCAGTAACCCG-1',
#  'ACATTGCAGTGGCGGA-1',
#  'ACATTGCAGTGTGATC-1',
#  'ACCAAACTCATAACGC-1',
#  'ACCAAACTCGTGCCTT-1',
#  'ACCAAACTCTGGCTTC-1',
#  'ACCAAACTCTTGCAGG-1',
#  'ACCAAGCGTAACTACG-1',
#  'ACCAAGCGTACTTAGG-1',
#  'ACCAAGCGTAGGTTTG-1',
#  'ACCAAGCGTAGTAAGA-1',
#  'ACCAAGCGTCGAAGTC-1',
#  'ACCAAGTTCAAACCGT-1',
#  'ACCAAGTTCCGCAAGC-1',
#  'ACCAAGTTCCTAATTC-1',
#  'ACCAAGTTCGTGCCTT-1',
#  'ACCAAGTTCTCAATGA-1',
#  'ACCAAGTTCTTGAGGT-1',
#  'ACCAATATCAACCAAC-1',
#  'ACCAATATCATTGACA-1',
#  'ACCAATATCCCTGACT-1',
#  'ACCAATATCGAAGTGA-1',
#  'ACCAATATCGTTTCCA-1',
#  'ACCACACCAATAGTCT-1',
#  'ACCACACCATAAGTCT-1',
#  'ACCACACCATCCTAGA-1',
#  'ACCACACCATGGAGGC-1',
#  'ACCACATAGCAACAAG-1',
#  'ACCACATAGCAAGGTA-1',
#  'ACCACATAGGAGGTTA-1',
#  'ACCACATAGGCTGTCA-1',
#  'ACCACATAGGGTTAGA-1',
#  'ACCACATAGGTAAGCA-1',
#  'ACCACATAGGTGTCCA-1',
#  'ACCACATAGTACTGGT-1',
#  'ACCACATAGTCGCTAG-1',
#  'ACCAGCTCAAACCTTG-1',
#  'ACCAGCTCAACTAGAA-1',
#  'ACCAGCTCACCTATAG-1',
#  'ACCAGCTCAGGCGAGT-1',
#  'ACCAGGACAAACGCGA-1',
#  'ACCAGGACAACCCTAA-1',
#  'ACCAGGACAACTGGGA-1',
#  'ACCAGGACACGTGCTG-1',
#  'ACCAGGACAGGCAAGC-1',
#  'ACCAGGACAGTTTACG-1',
#  'ACCAGGCTCAGTGAAG-1',
#  'ACCAGGCTCATGCAAC-1',
#  'ACCAGGCTCCGGTTAG-1',
#  'ACCAGGCTCTGCAAGT-1',
#  'ACCAGGCTCTGTAAGC-1',
#  'ACCAGGCTCTGTGCAG-1',
#  'ACCAGGCTCTTGCAAA-1',
#  'ACCAGGCTCTTGCAGG-1',
#  'ACCAGGCTCTTGTCCA-1',
#  'ACCAGGCTCTTTGTAC-1',
#  'ACCAGGGAGACAAACG-1',
#  'ACCAGGGAGCTATGAC-1',
#  'ACCAGGGAGGCATGAA-1',
#  'ACCAGGGAGGCTCATG-1',
#  'ACCAGGGAGGGACGCA-1',
#  'ACCAGGGAGTCATTTC-1',
#  'ACCATAATCCGTAAAC-1',
#  'ACCATAATCCTCATGC-1',
#  'ACCATTAAGCACGATT-1',
#  'ACCATTAAGCGCTCAA-1',
#  'ACCATTAAGCTTAACA-1',
#  'ACCATTAAGGAGGCAT-1',
#  'ACCATTAAGTACTGGT-1',
#  'ACCATTAAGTATTGGC-1',
#  'ACCCAACCAAGTGTTT-1',
#  'ACCCAACCAATCATGT-1',
#  'ACCCAACCAGCATGGA-1',
#  'ACCCAACCAGTAGGAT-1',
#  'ACCCAACCATTGTGCA-1',
#  'ACCCAGGGTCCGTGAG-1',
#  'ACCCAGGGTTACGCGG-1',
#  'ACCCAGGGTTGCATCT-1',
#  'ACCCGCTGTAGCTAGC-1',
#  'ACCCGCTGTCCTTAGT-1',
#  'ACCCGCTGTTGGTTAG-1',
#  'ACCCGTAAGACACTTA-1',
#  'ACCCGTAAGCATGCAT-1',
#  'ACCCGTAAGCCTGTTC-1',
#  'ACCCGTAAGGCGAATA-1',
#  'ACCCGTAAGGTTACAC-1',
#  'ACCCGTAAGTTAGTGC-1',
#  'ACCCTCCCAACTAGAA-1',
#  'ACCCTCCCAATCCTGA-1',
#  'ACCCTCCCAGCTCATA-1',
#  'ACCCTGTTCAATGTCA-1',
#  'ACCCTGTTCATAGACC-1',
#  'ACCCTGTTCTAAATCG-1',
#  'ACCGAAGCACTAAGAA-1',
#  'ACCGAAGCACTTGTTC-1',
#  'ACCGAAGCAGCTTAGC-1',
#  'ACCGAAGCAGGATTAA-1',
#  'ACCGAAGCAGTTAGCC-1',
#  'ACCGAAGCATAAGTTC-1',
#  'ACCGCAATCAAACCGT-1',
#  'ACCGCAATCCCTCTAA-1',
#  'ACCGGCTAGCGCAATT-1',
#  'ACCGGCTAGCTCATAA-1',
#  'ACCGGCTAGGCTGTGC-1',
#  'ACCGGCTAGTGAACAG-1',
#  'ACCGGTTCAAACGGGC-1',
#  'ACCGGTTCACAATACT-1',
#  'ACCGGTTCACCTAATG-1',
#  'ACCGGTTCACTCGCTC-1',
#  'ACCGGTTCAGGCCAAA-1',
#  'ACCGGTTCATTAAGTC-1',
#  'ACCTAAATCACTAGGT-1',
#  'ACCTAAATCATCGTTT-1',
#  'ACCTAAATCGTAACGT-1',
#  'ACCTAAATCTTTGTAC-1',
#  'ACCTAAGGTGAGACTC-1',
#  'ACCTAAGGTGCTGTAA-1',
#  'ACCTAAGGTGCTTACT-1',
#  'ACCTAAGGTGGTGAGA-1',
#  'ACCTAAGGTTTGAGCA-1',
#  'ACCTACCTCACTTCAT-1',
#  'ACCTACCTCATTACTC-1',
#  'ACCTACCTCCTGGCTT-1',
#  'ACCTACCTCGACCTGA-1',
#  'ACCTCACTCTAGCTTT-1',
#  'ACCTGGATCAGGTCCA-1',
#  'ACCTGGATCGCTAAAC-1',
#  'ACCTGGATCGGTCAAT-1',
#  'ACCTGGATCGTCAAGT-1',
#  'ACCTGGATCGTCCTTA-1',
#  'ACCTGGATCTAGCGTG-1',
#  'ACCTGGTCAAATTCGT-1',
#  'ACCTGGTCAACTAGGG-1',
#  'ACCTGGTCACAGCCTG-1',
#  'ACCTGGTCACCAGCAT-1',
#  'ACCTGGTCACGGTTTA-1',
#  'ACCTGGTCAGGATGGC-1',
#  'ACCTGGTCAGTAGCCT-1',
#  'ACCTGTTGTAACCTAG-1',
#  'ACCTGTTGTGAAGCCT-1',
#  'ACCTGTTGTGGAGCAA-1',
#  'ACCTGTTGTTGTCATC-1',
#  'ACCTTCATCAGCTAAC-1',
#  'ACCTTCATCCTGCGAA-1',
#  'ACCTTCATCGGTACGC-1',
#  'ACCTTCATCTCCTCTT-1',
#  'ACCTTCCAGACTTACA-1',
#  'ACCTTCCAGGTCCAAT-1',
#  'ACCTTCCAGGTCCACA-1',
#  'ACCTTCCAGTAACCAC-1',
#  'ACCTTCCAGTGTTGCG-1',
#  'ACCTTGCTCAATAGCC-1',
#  'ACCTTGCTCAGGAACA-1',
#  'ACCTTGCTCATTTGTC-1',
#  'ACCTTGCTCCAACTGG-1',
#  'ACCTTGCTCCGGTTGA-1',
#  'ACCTTGCTCGATCAGT-1',
#  'ACCTTGCTCGTTAGCG-1',
#  'ACCTTGCTCTCATCAT-1',
#  'ACCTTGTGTACCCACC-1',
#  'ACCTTGTGTGTGCACG-1',
#  'ACCTTGTGTTAAGCCA-1',
#  'ACCTTGTGTTCACCCA-1',
#  'ACCTTGTGTTCCGGGA-1',
#  'ACGAACAAGTAATCCA-1',
#  'ACGAACAAGTACTGGT-1',
#  'ACGAACAAGTCCTTCA-1',
#  'ACGAAGTCAAGTCGCT-1',
#  'ACGAAGTCAATTAGGA-1',
#  'ACGAAGTCACTCAACA-1',
#  'ACGAAGTCAGAGGGAG-1',
#  'ACGAAGTCATTAAAGG-1',
#  'ACGAATCTCAAACACC-1',
#  'ACGAATCTCCGGTTGA-1',
#  'ACGAATCTCCGTAAAC-1',
#  'ACGAATCTCCTCACTA-1',
#  'ACGAATCTCTAAGTGC-1',
#  'ACGAATCTCTCGCCTG-1',
#  'ACGAATCTCTTAAGTG-1',
#  'ACGACAAAGGAGCACG-1',
#  'ACGACAAAGGAGTCTT-1',
#  'ACGACAAAGTTTGGTA-1',
#  'ACGACTTAGCTTAACA-1',
#  'ACGACTTAGTCACCTC-1',
#  'ACGACTTAGTTATCCT-1',
#  'ACGAGTAAGACTATTG-1',
#  'ACGAGTAAGCCTAATA-1',
#  'ACGAGTAAGCTCAAAC-1',
#  'ACGAGTAAGGTCGATT-1',
#  'ACGAGTAAGGTTTACA-1',
#  'ACGATTCAGGAACACA-1',
#  'ACGATTCAGGCGAAAC-1',
#  'ACGATTCAGGTAGCTT-1',
#  'ACGATTCAGGTTAGAG-1',
#  'ACGATTCAGGTTTGCG-1',
#  'ACGCAAGCAATTGACT-1',
#  'ACGCAAGCACCAGGTT-1',
#  'ACGCAAGCACTAAGCC-1',
#  'ACGCAAGCAGGTTCAC-1',
#  'ACGCAAGCAGTACCGT-1',
#  'ACGCAAGCATAGGCGA-1',
#  'ACGCACGGTCAAGACC-1',
#  'ACGCACGGTCAGTAAT-1',
#  'ACGCACGGTCATAACG-1',
#  'ACGCACGGTCATAAGT-1',
#  'ACGCACGGTGAGAAAC-1',
#  'ACGCACGGTTAGGATT-1',
#  'ACGCACGGTTGCGCGA-1',
#  'ACGCCACAGAGGAGGA-1',
#  'ACGCCACAGAGGAGTC-1',
#  'ACGCCACAGCTGAGGG-1',
#  'ACGCCACAGCTTAGCG-1',
#  'ACGCCACAGGAGGTTA-1',
#  'ACGCCACAGTATTGTG-1',
#  'ACGCCACAGTCCTTTG-1',
#  'ACGCCTAAGCAGGCCT-1',
#  'ACGCCTAAGCCTAATA-1',
#  'ACGCCTAAGCGCTCAA-1',
#  'ACGCCTAAGGACCGCT-1',
#  'ACGCCTAAGGCGGGTA-1',
#  'ACGCCTAAGGCTAAGA-1',
#  'ACGCCTTTCACGAATC-1',
#  'ACGCCTTTCACTTCAT-1',
#  'ACGCCTTTCATTGTTC-1',
#  'ACGCCTTTCCCATAGG-1',
#  'ACGCCTTTCCGCTAGA-1',
#  'ACGCCTTTCGCTAAGT-1',
#  'ACGCTTGAGCATTATG-1',
#  'ACGCTTGAGGTTTACA-1',
#  'ACGGGAAGTACTGAAT-1',
#  'ACGGGAAGTCATCAAG-1',
#  'ACGGGAAGTGGTTCTT-1',
#  'ACGGGAAGTTGTTGGA-1',
#  'ACGGGAAGTTTATTCG-1',
#  'ACGGGAAGTTTGTTGC-1',
#  'ACGGTACGTACCAGGT-1',
#  'ACGGTACGTAGGTTTG-1',
#  'ACGGTACGTATCTGGA-1',
#  'ACGGTACGTCATCAAG-1',
#  'ACGGTACGTCCAAATG-1',
#  'ACGGTACGTGTCCAAA-1',
#  'ACGGTTAGTACCAGGT-1',
#  'ACGGTTAGTATTGCAG-1',
#  'ACGGTTAGTGTTAAAC-1',
#  'ACGGTTAGTTGGATAT-1',
#  'ACGGTTTAGCGATAGA-1',
#  'ACGGTTTAGCTACTGG-1',
#  'ACGGTTTAGTGATTCA-1',
#  'ACGTACCCACACAATT-1',
#  'ACGTACCCACAGGATG-1',
#  'ACGTACCCAGATTCAT-1',
#  'ACGTACCCAGCACGTT-1',
#  'ACGTACCCAGCGCTTG-1',
#  'ACGTACCCAGGCTGTT-1',
#  'ACGTACCCAGTTTGGC-1',
#  'ACGTACCCATAGCGGA-1',
#  'ACGTACCCATCCTAGA-1',
#  'ACGTACCCATTGTGGC-1',
#  'ACGTCAAGTAGGATCC-1',
#  'ACGTCAAGTCTAGCTT-1',
#  'ACGTCAAGTGTTTCAC-1',
#  'ACGTCCAAGCCTGAGC-1',
#  'ACGTCCAAGCTGTAAC-1',
#  'ACGTCCAAGCTTAACA-1',
#  'ACGTCCTTCACATTGA-1',
#  'ACGTCCTTCATTACGA-1',
#  'ACGTCCTTCATTGCGG-1',
#  'ACGTCCTTCCCTGGTT-1',
#  'ACGTCCTTCCGCTAGA-1',
#  'ACGTCCTTCGACCTGA-1',
#  'ACGTCCTTCGGGACCT-1',
#  'ACGTCCTTCTAAATCG-1',
#  'ACGTCCTTCTCCATGC-1',
#  'ACGTTACAGAGCCGCT-1',
#  'ACGTTACAGATTGAGG-1',
#  'ACGTTACAGCAGCTAT-1',
#  'ACGTTACAGCTCCCTG-1',
#  'ACGTTACAGGACCTCA-1',
#  'ACGTTACAGGCAAGTA-1',
#  'ACGTTACAGGGTGAGT-1',
#  'ACGTTACAGTTTGCGG-1',
#  'ACGTTGTAGCCTGACA-1',
#  'ACGTTGTAGCTCCCTG-1',
#  'ACGTTGTAGCTGGCTA-1',
#  'ACGTTGTAGGTAGCTT-1',
#  'ACGTTGTAGTAACCAC-1',
#  'ACGTTGTAGTTGTCTT-1',
#  'ACTAAAGCAACCTGGT-1',
#  'ACTAAAGCATGAGTTT-1',
#  'ACTAACCAGACAAAGT-1',
#  'ACTAACCAGATGGAGC-1',
#  'ACTAACCAGGGACTAA-1',
#  'ACTAACCAGGGTGGAT-1',
#  'ACTAACGGTAGCCATA-1',
#  'ACTAACGGTAGGTGTC-1',
#  'ACTAACGGTCATAACG-1',
#  'ACTAACGGTCGCATAA-1',
#  'ACTAACGGTTAGACCA-1',
#  'ACTAACGGTTTCCGGC-1',
#  'ACTAACGGTTTCGCCA-1',
#  'ACTAACTCACAGAACG-1',
#  'ACTAACTCACAGGGAC-1',
#  'ACTAACTCACATACTG-1',
#  'ACTAACTCACCAAAGG-1',
#  'ACTAACTCAGCAAGTG-1',
#  'ACTAACTCAGCCAGTT-1',
#  'ACTAATCCAATCCTAG-1',
#  'ACTAATCCACGTGCTG-1',
#  'ACTAATCCATGATTGT-1',
#  'ACTAATCCATGGCCCA-1',
#  'ACTAATCCATTAGGTT-1',
#  'ACTAGGCGTAACGTGC-1',
#  ...]

# %%
# Start from fragments file
adata = snap.pp.import_fragments(
    fragment_file=fragment_file,
    chrom_sizes=snap.genome.hg38,
    file=output_file,
    sorted_by_barcode=False,
    whitelist=whitelist,
    n_jobs=n_jobs,
)
adata
# Out:
# AnnData object with n_obs x n_vars = 9399 x 0 backed at 'results/1_qc_metrics/1633LM/1633LM.atac.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito'
#     uns: 'reference_sequences'
#     obsm: 'fragment_paired'

# %%
# Plot fragment size distribution
snap.pl.frag_size_distr(adata, interactive=False)
# Out:
# 2025-03-30 15:36:18 - INFO - Computing fragment size distribution...

# %%
# Compute TSSe scores of individual cells
snap.metrics.tsse(adata, snap.genome.hg38, n_jobs=n_jobs)
adata
# Out:
# AnnData object with n_obs x n_vars = 9399 x 0 backed at 'results/1_qc_metrics/1633LM/1633LM.atac.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#     uns: 'TSS_profile', 'frag_size_distr', 'library_tsse', 'reference_sequences', 'frac_overlap_TSS'
#     obsm: 'fragment_paired'

# %%
# Plot TSSe scores against number of unique fragments for each cell
snap.pl.tsse(adata, interactive=False)

# %%
# Create a cell by bin matrix
snap.pp.add_tile_matrix(adata, n_jobs=n_jobs)
adata
# Out:
# AnnData object with n_obs x n_vars = 9399 x 6062095 backed at 'results/1_qc_metrics/1633LM/1633LM.atac.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#     uns: 'TSS_profile', 'frag_size_distr', 'library_tsse', 'reference_sequences', 'frac_overlap_TSS'
#     obsm: 'fragment_paired'

# %%
# Select variable features (necessary for scrublet)
snap.pp.select_features(adata, blacklist=blacklist_file, n_jobs=n_jobs)
adata
# Out:
# 2025-03-30 15:36:42 - INFO - Selected 497782 features.
# AnnData object with n_obs x n_vars = 9399 x 6062095 backed at 'results/1_qc_metrics/1633LM/1633LM.atac.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#     var: 'count', 'selected'
#     uns: 'TSS_profile', 'frag_size_distr', 'library_tsse', 'reference_sequences', 'frac_overlap_TSS'
#     obsm: 'fragment_paired'

# %%
# Doublet detection
snap.pp.scrublet(adata, n_jobs=n_jobs)
adata
# Out:
# 2025-03-30 15:36:45 - INFO - Simulating doublets...
# 2025-03-30 15:36:46 - INFO - Spectral embedding ...
# 2025-03-30 15:37:21 - INFO - Calculating doublet scores...
# AnnData object with n_obs x n_vars = 9399 x 6062095 backed at 'results/1_qc_metrics/1633LM/1633LM.atac.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse', 'doublet_probability', 'doublet_score'
#     var: 'count', 'selected'
#     uns: 'TSS_profile', 'scrublet_sim_doublet_score', 'frag_size_distr', 'library_tsse', 'reference_sequences', 'frac_overlap_TSS'
#     obsm: 'fragment_paired'

# %%
# Close object (saves to disk)
adata.close()
adata
# Out:
# Closed AnnData object
