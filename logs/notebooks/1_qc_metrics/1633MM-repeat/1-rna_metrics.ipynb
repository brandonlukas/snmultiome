# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys;sys.path.extend(['/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12/site-packages', '/home/brandon/code/pingyin/snmultiome/workflow/rules', '/home/brandon/code/pingyin/snmultiome/workflow', '/home/brandon/miniconda3/envs/snapatac2_env/bin', '/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12', '/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12/lib-dynload', '/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12/site-packages', '/home/brandon/.cache/snakemake/snakemake/source-cache/runtime-cache/tmpl3iz42yn/file/home/brandon/code/pingyin/snmultiome/workflow/rules/../notebooks/1_qc_metrics', '/home/brandon/code/pingyin/snmultiome/workflow/rules/../notebooks/1_qc_metrics']);import pickle;from snakemake import script;script.snakemake = pickle.loads(b'\x80\x04\x95\xdd\x05\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94\x8c9results/0_initialization/1633MM-repeat/1633MM-repeat.h5mu\x94a}\x94(\x8c\x06_names\x94}\x94\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x10h\x06\x8c\x0eAttributeGuard\x94\x93\x94)\x81\x94}\x94\x8c\x04name\x94h\x10sbh\x11h\x13)\x81\x94}\x94h\x16h\x11sbub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8c9results/1_qc_metrics/1633MM-repeat/1633MM-repeat.rna.h5ad\x94a}\x94(h\x0c}\x94h\x0e]\x94(h\x10h\x11eh\x10h\x13)\x81\x94}\x94h\x16h\x10sbh\x11h\x13)\x81\x94}\x94h\x16h\x11sbub\x8c\r_params_store\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x0c}\x94h\x0e]\x94(h\x10h\x11eh\x10h\x13)\x81\x94}\x94h\x16h\x10sbh\x11h\x13)\x81\x94}\x94h\x16h\x11sbub\x8c\r_params_types\x94}\x94\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\r1633MM-repeat\x94a}\x94(h\x0c}\x94\x8c\x06sample\x94K\x00N\x86\x94sh\x0e]\x94(h\x10h\x11eh\x10h\x13)\x81\x94}\x94h\x16h\x10sbh\x11h\x13)\x81\x94}\x94h\x16h\x11sb\x8c\x06sample\x94h6ub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x0c}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x0e]\x94(h\x10h\x11eh\x10h\x13)\x81\x94}\x94h\x16h\x10sbh\x11h\x13)\x81\x94}\x94h\x16h\x11sbhIK\x01hKK\x01hMhFub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c=logs/notebooks/1_qc_metrics/1633MM-repeat/1-rna_metrics.ipynb\x94a}\x94(h\x0c}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x0e]\x94(h\x10h\x11eh\x10h\x13)\x81\x94}\x94h\x16h\x10sbh\x11h\x13)\x81\x94}\x94h\x16h\x11sbh[hXub\x8c\x06config\x94}\x94(\x8c\x08data_dir\x94\x8c,/home/brandon/data/pingyin/snmultiome/input/\x94\x8c\x0bresults_dir\x94\x8c\x08results/\x94\x8c\x07samples\x94]\x94(\x8c\x061619LM\x94\x8c\x061619MM\x94\x8c\x061633LM\x94\x8c\r1633MM-repeat\x94e\x8c\x03RNA\x94}\x94(\x8c\x10celltypist_model\x94\x8c\x1bHuman_Endometrium_Atlas.pkl\x94\x8c\x02qc\x94}\x94(\x8c\tmin_genes\x94K\xc8\x8c\nmin_counts\x94M\xf4\x01\x8c\rpct_counts_mt\x94K\x05\x8c\x0fpct_counts_ribo\x94K\x05\x8c\rdoublet_score\x94G?\xd3333333\x8c\tmin_cells\x94K\x03uu\x8c\x04ATAC\x94}\x94(\x8c\tblacklist\x94\x8c\x1fresources/hg38-blacklist.v2.bed\x94\x8c\x02qc\x94}\x94(\x8c\x08min_tsse\x94K\x07\x8c\nmin_counts\x94M\xe8\x03\x8c\tmin_cells\x94K\x03uuu\x8c\x04rule\x94\x8c\x0brna_metrics\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cN/home/brandon/code/pingyin/snmultiome/workflow/rules/../notebooks/1_qc_metrics\x94ub.');del script;from snakemake.logging import logger;from snakemake.script import snakemake;import os; os.chdir(r'/home/brandon/code/pingyin/snmultiome');
######## snakemake preamble end #########

# %% [markdown]
# # Compute RNA QC metrics

# %%
# Load libraries
import muon as mu
import scanpy as sc
from snakemake.script import snakemake

# %%
# Read input and output paths from Snakemake
input_file = snakemake.input[0]
output_file = snakemake.output[0]

# %%
# Load the data
mdata = mu.read(input_file)
mdata
# Out:
# /home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12/site-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12/site-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
# MuData object with n_obs × n_vars = 6857 × 98016
# ...

# %%
# Focus on the RNA modality
adata = mdata.mod["rna"]
adata
# Out:
# AnnData object with n_obs × n_vars = 6857 × 36601
#     var: 'gene_ids'

# %%
# Mark mitochondrial, ribosomal, and hemoglobin genes
adata.var["mt"] = adata.var_names.str.startswith("MT-")
adata.var["ribo"] = adata.var_names.str.startswith(("RPS", "RPL"))
adata.var["hb"] = adata.var_names.str.contains("^HB[^(P)]")
adata
# Out:
# AnnData object with n_obs × n_vars = 6857 × 36601
#     var: 'gene_ids', 'mt', 'ribo', 'hb'

# %%
# Calculate quality control metrics
sc.pp.calculate_qc_metrics(
    adata,
    qc_vars=["mt", "ribo", "hb"],
    percent_top=None,
    inplace=True,
    log1p=False,
)
adata
# Out:
# AnnData object with n_obs × n_vars = 6857 × 36601
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'pct_counts_hb'
#     var: 'gene_ids', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
# Inspect violin plots of QC metrics
sc.pl.violin(
    adata,
    ["n_genes_by_counts", "total_counts", "pct_counts_mt"],
    jitter=0.4,
    multi_panel=True,
)

# %%
# Consider QC metrics jointly by inspecting a scatter plot colored by `pct_counts_mt`
sc.pl.scatter(adata, "total_counts", "n_genes_by_counts", color="pct_counts_mt")

# %%
# Doublet detection
sc.pp.scrublet(adata)
adata
# Out:
# AnnData object with n_obs × n_vars = 6857 × 36601
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'pct_counts_hb', 'doublet_score', 'predicted_doublet'
#     var: 'gene_ids', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'scrublet'

# %%
# Save updated mdata
adata.write(output_file)
