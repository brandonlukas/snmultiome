# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys;sys.path.extend(['/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12/site-packages', '/home/brandon/code/pingyin/snmultiome/workflow/rules', '/home/brandon/code/pingyin/snmultiome/workflow', '/home/brandon/miniconda3/envs/snapatac2_env/bin', '/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12', '/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12/lib-dynload', '/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12/site-packages', '/home/brandon/.cache/snakemake/snakemake/source-cache/runtime-cache/tmpl3iz42yn/file/home/brandon/code/pingyin/snmultiome/workflow/rules/../notebooks/1_qc_metrics', '/home/brandon/code/pingyin/snmultiome/workflow/rules/../notebooks/1_qc_metrics']);import pickle;from snakemake import script;script.snakemake = pickle.loads(b'\x80\x04\x95\xe8\x06\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c9results/0_initialization/1633MM-repeat/1633MM-repeat.h5mu\x94\x8cT/home/brandon/data/pingyin/snmultiome/input/1633MM-repeat/outs/atac_fragments.tsv.gz\x94\x8ci/home/brandon/data/pingyin/snmultiome/input/1633MM-repeat/outs/filtered_feature_bc_matrix/barcodes.tsv.gz\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\tfragments\x94K\x01N\x86\x94\x8c\x08barcodes\x94K\x02N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x16h\x06\x8c\x0eAttributeGuard\x94\x93\x94)\x81\x94}\x94\x8c\x04name\x94h\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sbh\x10h\x0bh\x12h\x0cub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8c:results/1_qc_metrics/1633MM-repeat/1633MM-repeat.atac.h5ad\x94a}\x94(h\x0e}\x94h\x14]\x94(h\x16h\x17eh\x16h\x19)\x81\x94}\x94h\x1ch\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sbub\x8c\r_params_store\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94\x8c\x1fresources/hg38-blacklist.v2.bed\x94a}\x94(h\x0e}\x94\x8c\tblacklist\x94K\x00N\x86\x94sh\x14]\x94(h\x16h\x17eh\x16h\x19)\x81\x94}\x94h\x1ch\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sbh2h/ub\x8c\r_params_types\x94}\x94\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\r1633MM-repeat\x94a}\x94(h\x0e}\x94\x8c\x06sample\x94K\x00N\x86\x94sh\x14]\x94(h\x16h\x17eh\x16h\x19)\x81\x94}\x94h\x1ch\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sb\x8c\x06sample\x94h?ub\x8c\x07threads\x94K\x0c\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x0cK\x01\x8c\x04/tmp\x94e}\x94(h\x0e}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x14]\x94(h\x16h\x17eh\x16h\x19)\x81\x94}\x94h\x1ch\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sbhRK\x0chTK\x01hVhOub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c>logs/notebooks/1_qc_metrics/1633MM-repeat/2-atac_metrics.ipynb\x94a}\x94(h\x0e}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x14]\x94(h\x16h\x17eh\x16h\x19)\x81\x94}\x94h\x1ch\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sbhdhaub\x8c\x06config\x94}\x94(\x8c\x08data_dir\x94\x8c,/home/brandon/data/pingyin/snmultiome/input/\x94\x8c\x0bresults_dir\x94\x8c\x08results/\x94\x8c\x07samples\x94]\x94(\x8c\x061619LM\x94\x8c\x061619MM\x94\x8c\x061633LM\x94\x8c\r1633MM-repeat\x94e\x8c\x03RNA\x94}\x94(\x8c\x10celltypist_model\x94\x8c\x1bHuman_Endometrium_Atlas.pkl\x94\x8c\x02qc\x94}\x94(\x8c\tmin_genes\x94K\xc8\x8c\nmin_counts\x94M\xf4\x01\x8c\rpct_counts_mt\x94K\x05\x8c\x0fpct_counts_ribo\x94K\x05\x8c\rdoublet_score\x94G?\xd3333333\x8c\tmin_cells\x94K\x03uu\x8c\x04ATAC\x94}\x94(\x8c\tblacklist\x94h/\x8c\x02qc\x94}\x94(\x8c\x08min_tsse\x94K\x07\x8c\nmin_counts\x94M\xe8\x03\x8c\tmin_cells\x94K\x03uuu\x8c\x04rule\x94\x8c\x0catac_metrics\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cN/home/brandon/code/pingyin/snmultiome/workflow/rules/../notebooks/1_qc_metrics\x94ub.');del script;from snakemake.logging import logger;from snakemake.script import snakemake;import os; os.chdir(r'/home/brandon/code/pingyin/snmultiome');
######## snakemake preamble end #########

# %% [markdown]
# # Compute ATAC QC metrics

# %%
# Load libraries
import snapatac2 as snap
import pandas as pd
from snakemake.script import snakemake

# %%
# Read input and output paths from Snakemake
fragment_file = snakemake.input["fragments"]
barcodes_file = snakemake.input["barcodes"]
output_file = snakemake.output[0]
n_jobs = snakemake.threads
blacklist_file = snakemake.params.get("blacklist", None)

# %%
# Extract list of barcodes
whitelist = pd.read_csv(barcodes_file, header=None)[0].tolist()
whitelist
# Out:
# ['AAACAGCCAACTAGAA-1',
#  'AAACAGCCAAGCCACT-1',
#  'AAACAGCCACTTACAG-1',
#  'AAACAGCCATCAGTAT-1',
#  'AAACAGCCATGCTTAG-1',
#  'AAACAGCCATTCCTGT-1',
#  'AAACATGCACAATTAC-1',
#  'AAACATGCAGAAATGC-1',
#  'AAACATGCATCGCTCC-1',
#  'AAACATGCATGAGTTT-1',
#  'AAACCAACAGGCATCT-1',
#  'AAACCAACATTAAGTC-1',
#  'AAACCAACATTGTGTG-1',
#  'AAACCGAAGCACTTGG-1',
#  'AAACCGAAGCGGTTAT-1',
#  'AAACCGAAGTGTTGTA-1',
#  'AAACCGCGTTCCTGTG-1',
#  'AAACCGGCAAGACTCC-1',
#  'AAACCGGCAGGTTAAA-1',
#  'AAACCGGCATAAGTCT-1',
#  'AAACGCGCACAACAGG-1',
#  'AAACGCGCACAATTAC-1',
#  'AAACGCGCATTGCGGT-1',
#  'AAACGGATCATAGCCG-1',
#  'AAACGGATCGCTAAAC-1',
#  'AAACGGATCTTGCAAA-1',
#  'AAACGGATCTTGTCTG-1',
#  'AAACGTACAATTAAGG-1',
#  'AAACGTACACTTACAG-1',
#  'AAACGTACAGACAAAC-1',
#  'AAACGTACATCTTGAG-1',
#  'AAACGTACATTAAAGG-1',
#  'AAAGCAAGTACTGAAT-1',
#  'AAAGCAAGTAGCAGCT-1',
#  'AAAGCAAGTTCCGCAC-1',
#  'AAAGCAAGTTGTGACA-1',
#  'AAAGCACCACCTGCTC-1',
#  'AAAGCCCGTAGGTTTG-1',
#  'AAAGCCCGTGCTGTAA-1',
#  'AAAGCCCGTGTTTGCT-1',
# ...

# %%
# Start from fragments file
adata = snap.pp.import_fragments(
    fragment_file=fragment_file,
    chrom_sizes=snap.genome.hg38,
    file=output_file,
    sorted_by_barcode=False,
    whitelist=whitelist,
    n_jobs=n_jobs,
)
adata
# Out:
# AnnData object with n_obs x n_vars = 6817 x 0 backed at 'results/1_qc_metrics/1633MM-repeat/1633MM-repeat.atac.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito'
#     uns: 'reference_sequences'
#     obsm: 'fragment_paired'

# %%
# Plot fragment size distribution
snap.pl.frag_size_distr(adata, interactive=False)
# Out:
# 2025-03-30 15:34:42 - INFO - Computing fragment size distribution...

# %%
# Compute TSSe scores of individual cells
snap.metrics.tsse(adata, snap.genome.hg38, n_jobs=n_jobs)
adata
# Out:
# AnnData object with n_obs x n_vars = 6817 x 0 backed at 'results/1_qc_metrics/1633MM-repeat/1633MM-repeat.atac.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#     uns: 'TSS_profile', 'frac_overlap_TSS', 'reference_sequences', 'library_tsse', 'frag_size_distr'
#     obsm: 'fragment_paired'

# %%
# Plot TSSe scores against number of unique fragments for each cell
snap.pl.tsse(adata, interactive=False)

# %%
# Create a cell by bin matrix
snap.pp.add_tile_matrix(adata, n_jobs=n_jobs)
adata
# Out:
# AnnData object with n_obs x n_vars = 6817 x 6062095 backed at 'results/1_qc_metrics/1633MM-repeat/1633MM-repeat.atac.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#     uns: 'TSS_profile', 'frac_overlap_TSS', 'reference_sequences', 'library_tsse', 'frag_size_distr'
#     obsm: 'fragment_paired'

# %%
# Select variable features (necessary for scrublet)
snap.pp.select_features(adata, blacklist=blacklist_file, n_jobs=n_jobs)
adata
# Out:
# 2025-03-30 15:35:19 - INFO - Selected 497317 features.
# AnnData object with n_obs x n_vars = 6817 x 6062095 backed at 'results/1_qc_metrics/1633MM-repeat/1633MM-repeat.atac.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#     var: 'count', 'selected'
#     uns: 'TSS_profile', 'frac_overlap_TSS', 'reference_sequences', 'library_tsse', 'frag_size_distr'
#     obsm: 'fragment_paired'

# %%
# Doublet detection
snap.pp.scrublet(adata, n_jobs=n_jobs)
adata
# Out:
# 2025-03-30 15:35:27 - INFO - Simulating doublets...
# 2025-03-30 15:35:27 - INFO - Spectral embedding ...
# 2025-03-30 15:36:16 - INFO - Calculating doublet scores...
# AnnData object with n_obs x n_vars = 6817 x 6062095 backed at 'results/1_qc_metrics/1633MM-repeat/1633MM-repeat.atac.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse', 'doublet_probability', 'doublet_score'
#     var: 'count', 'selected'
#     uns: 'TSS_profile', 'scrublet_sim_doublet_score', 'frac_overlap_TSS', 'reference_sequences', 'library_tsse', 'frag_size_distr'
#     obsm: 'fragment_paired'

# %%
# Close object (saves to disk)
adata.close()
adata
# Out:
# Closed AnnData object
