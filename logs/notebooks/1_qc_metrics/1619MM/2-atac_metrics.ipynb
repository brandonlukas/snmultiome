# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys;sys.path.extend(['/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12/site-packages', '/home/brandon/code/pingyin/snmultiome/workflow/rules', '/home/brandon/code/pingyin/snmultiome/workflow', '/home/brandon/miniconda3/envs/snapatac2_env/bin', '/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12', '/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12/lib-dynload', '/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12/site-packages', '/home/brandon/.cache/snakemake/snakemake/source-cache/runtime-cache/tmpl3iz42yn/file/home/brandon/code/pingyin/snmultiome/workflow/rules/../notebooks/1_qc_metrics', '/home/brandon/code/pingyin/snmultiome/workflow/rules/../notebooks/1_qc_metrics']);import pickle;from snakemake import script;script.snakemake = pickle.loads(b'\x80\x04\x95\xb0\x06\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c+results/0_initialization/1619MM/1619MM.h5mu\x94\x8cM/home/brandon/data/pingyin/snmultiome/input/1619MM/outs/atac_fragments.tsv.gz\x94\x8cb/home/brandon/data/pingyin/snmultiome/input/1619MM/outs/filtered_feature_bc_matrix/barcodes.tsv.gz\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\tfragments\x94K\x01N\x86\x94\x8c\x08barcodes\x94K\x02N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x16h\x06\x8c\x0eAttributeGuard\x94\x93\x94)\x81\x94}\x94\x8c\x04name\x94h\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sbh\x10h\x0bh\x12h\x0cub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8c,results/1_qc_metrics/1619MM/1619MM.atac.h5ad\x94a}\x94(h\x0e}\x94h\x14]\x94(h\x16h\x17eh\x16h\x19)\x81\x94}\x94h\x1ch\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sbub\x8c\r_params_store\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94\x8c\x1fresources/hg38-blacklist.v2.bed\x94a}\x94(h\x0e}\x94\x8c\tblacklist\x94K\x00N\x86\x94sh\x14]\x94(h\x16h\x17eh\x16h\x19)\x81\x94}\x94h\x1ch\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sbh2h/ub\x8c\r_params_types\x94}\x94\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\x061619MM\x94a}\x94(h\x0e}\x94\x8c\x06sample\x94K\x00N\x86\x94sh\x14]\x94(h\x16h\x17eh\x16h\x19)\x81\x94}\x94h\x1ch\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sb\x8c\x06sample\x94h?ub\x8c\x07threads\x94K\x0c\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x0cK\x01\x8c\x04/tmp\x94e}\x94(h\x0e}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x14]\x94(h\x16h\x17eh\x16h\x19)\x81\x94}\x94h\x1ch\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sbhRK\x0chTK\x01hVhOub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c7logs/notebooks/1_qc_metrics/1619MM/2-atac_metrics.ipynb\x94a}\x94(h\x0e}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x14]\x94(h\x16h\x17eh\x16h\x19)\x81\x94}\x94h\x1ch\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sbhdhaub\x8c\x06config\x94}\x94(\x8c\x08data_dir\x94\x8c,/home/brandon/data/pingyin/snmultiome/input/\x94\x8c\x0bresults_dir\x94\x8c\x08results/\x94\x8c\x07samples\x94]\x94(\x8c\x061619LM\x94\x8c\x061619MM\x94\x8c\x061633LM\x94\x8c\r1633MM-repeat\x94e\x8c\x03RNA\x94}\x94(\x8c\x10celltypist_model\x94\x8c\x1bHuman_Endometrium_Atlas.pkl\x94\x8c\x02qc\x94}\x94(\x8c\tmin_genes\x94K\xc8\x8c\nmin_counts\x94M\xf4\x01\x8c\rpct_counts_mt\x94K\x05\x8c\x0fpct_counts_ribo\x94K\x05\x8c\rdoublet_score\x94G?\xd3333333\x8c\tmin_cells\x94K\x03uu\x8c\x04ATAC\x94}\x94(\x8c\tblacklist\x94h/\x8c\x02qc\x94}\x94(\x8c\x08min_tsse\x94K\x07\x8c\nmin_counts\x94M\xe8\x03\x8c\tmin_cells\x94K\x03uuu\x8c\x04rule\x94\x8c\x0catac_metrics\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cN/home/brandon/code/pingyin/snmultiome/workflow/rules/../notebooks/1_qc_metrics\x94ub.');del script;from snakemake.logging import logger;from snakemake.script import snakemake;import os; os.chdir(r'/home/brandon/code/pingyin/snmultiome');
######## snakemake preamble end #########

# %% [markdown]
# # Compute ATAC QC metrics

# %%
# Load libraries
import snapatac2 as snap
import pandas as pd
from snakemake.script import snakemake

# %%
# Read input and output paths from Snakemake
fragment_file = snakemake.input["fragments"]
barcodes_file = snakemake.input["barcodes"]
output_file = snakemake.output[0]
n_jobs = snakemake.threads
blacklist_file = snakemake.params.get("blacklist", None)

# %%
# Extract list of barcodes
whitelist = pd.read_csv(barcodes_file, header=None)[0].tolist()
whitelist
# Out:
# ['AAACAGCCATCCGTAA-1',
#  'AAACAGCCATGGTTAT-1',
#  'AAACATGCAACACCTA-1',
#  'AAACATGCAAGGCCAA-1',
#  'AAACATGCACAATTAC-1',
#  'AAACATGCAGCTAATT-1',
#  'AAACATGCAGGCAAGC-1',
#  'AAACATGCAGTGAACG-1',
#  'AAACATGCATGACTAT-1',
#  'AAACATGCATGCAACC-1',
#  'AAACCAACAAACGGGC-1',
#  'AAACCAACAACAACAA-1',
#  'AAACCGAAGAGGAAGG-1',
#  'AAACCGAAGTGCTGTG-1',
#  'AAACCGCGTAAAGCAA-1',
#  'AAACCGCGTAGTAAGA-1',
#  'AAACCGCGTCGAAGTC-1',
#  'AAACCGCGTTGTGACA-1',
#  'AAACCGCGTTTCAGGA-1',
#  'AAACCGCGTTTCGCCA-1',
#  'AAACCGGCAACAACAA-1',
#  'AAACCGGCAGCTTAAT-1',
#  'AAACCGGCATCCAGGT-1',
#  'AAACCGGCATGCTATG-1',
#  'AAACGCGCAAGCCAGA-1',
#  'AAACGCGCAATAGCCC-1',
#  'AAACGCGCACCTCAGG-1',
#  'AAACGCGCATAATGTC-1',
#  'AAACGCGCATGAAGTA-1',
#  'AAACGGATCACAGACT-1',
#  'AAACGGATCCCTCTAA-1',
#  'AAACGGATCGGCCAGT-1',
#  'AAACGGATCGTTATAG-1',
#  'AAACGTACACTTCACT-1',
#  'AAACGTACAGGTTATT-1',
#  'AAAGCAAGTAGACAAA-1',
#  'AAAGCAAGTGGTTATG-1',
#  'AAAGCAAGTTAATGAC-1',
#  'AAAGCAAGTTATCCGT-1',
#  'AAAGCAAGTTGCGTAA-1',
#  'AAAGCACCAAGATTCT-1',
#  'AAAGCACCACAAGCCT-1',
#  'AAAGCACCACAGGATG-1',
#  'AAAGCACCAGCCGCTA-1',
#  'AAAGCACCATGATTGT-1',
#  'AAAGCCCGTATTGAGT-1',
#  'AAAGCCCGTGACATAT-1',
#  'AAAGCCCGTGAGGTAG-1',
#  'AAAGCCCGTGCTCCGT-1',
#  'AAAGCCCGTTGTTCAC-1',
#  'AAAGCCGCATTGTCCT-1',
#  'AAAGCGGGTAGTTGGC-1',
#  'AAAGCGGGTCTAGCTT-1',
#  'AAAGCTTGTAGCCATA-1',
#  'AAAGCTTGTTGTTGGA-1',
#  'AAAGGACGTATTGAGT-1',
#  'AAAGGACGTGTTGCTT-1',
#  'AAAGGACGTGTTTGAG-1',
#  'AAAGGACGTTAACACG-1',
#  'AAAGGACGTTTATTCG-1',
#  'AAAGGACGTTTGTGGA-1',
#  'AAAGGAGCACAAAGCG-1',
#  'AAAGGAGCAGCAAGAT-1',
#  'AAAGGAGCAGGCGATA-1',
#  'AAAGGAGCAGGTTATT-1',
#  'AAAGGAGCAGTAAGTA-1',
#  'AAAGGAGCATTATGGT-1',
#  'AAAGGCTCAAAGCTCC-1',
#  'AAAGGCTCACATACTG-1',
#  'AAAGGCTCAGGCGAGT-1',
#  'AAAGGCTCATAATCGT-1',
#  'AAAGGCTCATGGTTAT-1',
#  'AAAGGTTAGACTTACA-1',
#  'AAAGGTTAGATAGACG-1',
#  'AAAGGTTAGCCACATG-1',
#  'AAAGGTTAGCTAATTG-1',
#  'AAAGGTTAGGAAGTAT-1',
#  'AAAGGTTAGGAGTCTT-1',
#  'AAATCCGGTAAACAAG-1',
#  'AAATCCGGTCCAAATG-1',
#  'AAATCCGGTGCAATGC-1',
#  'AAATCCGGTTCACCCA-1',
#  'AAATCCGGTTGTAAAC-1',
#  'AAATCCGGTTTCCTCC-1',
#  'AAATGCCTCATAAGCC-1',
#  'AAATGCCTCATGGCTG-1',
#  'AAATGCCTCCGCAACA-1',
#  'AAATGCCTCCTCCATA-1',
#  'AAATGCCTCCTGAATA-1',
#  'AAATGCCTCGCAGGCT-1',
#  'AAATGCCTCTGGCATG-1',
#  'AAATGCCTCTGTAATG-1',
#  'AAATGCCTCTTAATGG-1',
#  'AAATGGCCAACTGGCT-1',
#  'AAATGGCCACCTGGTG-1',
#  'AAATGGCCAGCAGGTA-1',
#  'AAATGGCCATGGAGGC-1',
#  'AAATGGCCATGGCCCA-1',
#  'AACAAAGGTCAATACG-1',
#  'AACAAAGGTGCATTAG-1',
#  'AACAAAGGTTAAGTGT-1',
#  'AACAAAGGTTAGCTGA-1',
#  'AACAAAGGTTCCTCCT-1',
#  'AACAAAGGTTGAAGCC-1',
#  'AACAAAGGTTGCCTCA-1',
#  'AACAAAGGTTGCGTAA-1',
#  'AACAAAGGTTTCGCGC-1',
#  'AACAAGCCAACACCTA-1',
#  'AACAGATAGGACAATG-1',
#  'AACAGATAGTTAGCCG-1',
#  'AACAGCAAGGCGCATC-1',
#  'AACAGCAAGTTATCCT-1',
#  'AACAGGATCGTTAAGC-1',
#  'AACAGGATCTCCTCAA-1',
#  'AACATAGCACATGCTA-1',
#  'AACATAGCAGAGGGAG-1',
#  'AACATAGCAGTTGCGT-1',
#  'AACATCATCACGTTAA-1',
#  'AACATCATCATTAGCA-1',
#  'AACATCATCCTTCGTA-1',
#  'AACATCATCGGGCCAT-1',
#  'AACATTGTCAATTGGC-1',
#  'AACATTGTCCCGAAGC-1',
#  'AACATTGTCCTCATCA-1',
#  'AACATTGTCCTTCGTA-1',
#  'AACATTGTCGATATTG-1',
#  'AACATTGTCGGTAACT-1',
#  'AACATTGTCTAACCTT-1',
#  'AACCCGCAGACAACAG-1',
#  'AACCCGCAGCAGGCCT-1',
#  'AACCCGCAGCGAGTAA-1',
#  'AACCCGCAGCGCCTTT-1',
#  'AACCCGCAGCTTCTCA-1',
#  'AACCCGCAGGGCTTAT-1',
#  'AACCCGCAGTCATCCC-1',
#  'AACCCGCAGTTGTCTT-1',
#  'AACCGCTCAATAACGA-1',
#  'AACCGCTCAGGAACCA-1',
#  'AACCGCTCATGTCAAT-1',
#  'AACCGCTCATTGTGAT-1',
#  'AACCGGCTCATAACCA-1',
#  'AACCGGCTCATCGTTT-1',
#  'AACCGGCTCGGGATTT-1',
#  'AACCTAATCAAGACTC-1',
#  'AACCTAATCGTAATCA-1',
#  'AACCTAATCTGTGAGT-1',
#  'AACCTCACAACCCTAA-1',
#  'AACCTCACACCTGCTC-1',
#  'AACCTCACAGGAAGCC-1',
#  'AACCTCACATACCCGG-1',
#  'AACCTCCTCACCATTT-1',
#  'AACCTCCTCATGCAAC-1',
#  'AACCTCCTCCTGCGAA-1',
#  'AACCTCCTCGTTCACC-1',
#  'AACCTTAAGAAAGGAA-1',
#  'AACCTTAAGCAACATC-1',
#  'AACCTTAAGCAAGGGT-1',
#  'AACCTTAAGGAACCAA-1',
#  'AACCTTAAGGACCGCT-1',
#  'AACCTTAAGGACGTAA-1',
#  'AACCTTGCAAACCTTG-1',
#  'AACCTTGCACCTCGCT-1',
#  'AACCTTGCAGGCCAAA-1',
#  'AACCTTGCAGGCCATT-1',
#  'AACCTTGCAGGTTCAC-1',
#  'AACGACAAGTCAGGCC-1',
#  'AACGCCCAGAAAGCAT-1',
#  'AACGCCCAGACAAAGT-1',
#  'AACGCCCAGCCAGGTC-1',
#  'AACGCCCAGGCAAGTA-1',
#  'AACGCCCAGGCAGGTG-1',
#  'AACGCCCAGTGAGGTA-1',
#  'AACGCTAGTCATCAAG-1',
#  'AACGCTAGTCCTTCAG-1',
#  'AACGCTAGTGATCATG-1',
#  'AACGCTAGTTAACGGC-1',
#  'AACGCTAGTTTGTCTA-1',
#  'AACGGTAAGCTTCTCA-1',
#  'AACGGTAAGGCTATGT-1',
#  'AACGGTAAGTAGCGCC-1',
#  'AACGGTAAGTCACTCC-1',
#  'AACTACTCAAGCCAGA-1',
#  'AACTACTCAAGCTAAA-1',
#  'AACTACTCAAGGTACG-1',
#  'AACTACTCACCAAAGG-1',
#  'AACTACTCACCTCGCT-1',
#  'AACTACTCACGTTACA-1',
#  'AACTACTCAGCAAATA-1',
#  'AACTACTCAGTAGCCT-1',
#  'AACTACTCATCCCTCA-1',
#  'AACTACTCATCCTAGA-1',
#  'AACTACTCATGTTGGC-1',
#  'AACTAGCTCATCGTTT-1',
#  'AACTAGCTCCCGTTAC-1',
#  'AACTAGCTCGCAGGCT-1',
#  'AACTAGCTCGTGCCTT-1',
#  'AACTAGTGTCCTAATC-1',
#  'AACTAGTGTGAGGTAG-1',
#  'AACTCACAGACCATAC-1',
#  'AACTCACAGCTGTCAG-1',
#  'AACTCACAGGCAATAG-1',
#  'AACTCACAGGTCAAAG-1',
#  'AACTCACAGTTCCCAC-1',
#  'AACTGTTCACCTGGTG-1',
#  'AACTGTTCATTGTGGC-1',
#  'AACTTAGTCACTTTAC-1',
#  'AACTTAGTCCAGGAAA-1',
#  'AACTTAGTCGGCTATG-1',
#  'AACTTAGTCGGTTCCT-1',
#  'AACTTAGTCGTTACAA-1',
#  'AAGAACAGTACCGTAA-1',
#  'AAGAACAGTAGCCTCC-1',
#  'AAGAACAGTAGTAAGA-1',
#  'AAGAACAGTCAATGTG-1',
#  'AAGAACAGTTAGACCA-1',
#  'AAGAACAGTTCCTGTG-1',
#  'AAGAACAGTTGTGACA-1',
#  'AAGAATCAGGCATTAC-1',
#  'AAGAATCAGTATTGTG-1',
#  'AAGAATCAGTGAACCT-1',
#  'AAGACAAGTGCAACTA-1',
#  'AAGACAAGTTATGTGG-1',
#  'AAGACATAGCCTAATA-1',
#  'AAGACATAGGAACGGT-1',
#  'AAGACATAGTCAATTG-1',
#  'AAGACATAGTTAGACC-1',
#  'AAGACCAAGGACTAAG-1',
#  'AAGACCAAGGAGGGTT-1',
#  'AAGACCAAGGCTCATG-1',
#  'AAGACCAAGTCACCAG-1',
#  'AAGACCAAGTCTATGA-1',
#  'AAGACCAAGTTCCTCA-1',
#  'AAGCAAGTCACTTCAT-1',
#  'AAGCAAGTCATCCACC-1',
#  'AAGCAAGTCATCCTCA-1',
#  'AAGCAAGTCATGCTCC-1',
#  'AAGCAAGTCCTAACGG-1',
#  'AAGCAAGTCCTTAGTT-1',
#  'AAGCAAGTCGCTCACT-1',
#  'AAGCAAGTCGTTAACA-1',
#  'AAGCAAGTCTAACTGA-1',
#  'AAGCATGAGACAGGCG-1',
#  'AAGCATGAGACCATAC-1',
#  'AAGCATGAGCAAGATG-1',
#  'AAGCATGAGCGATACT-1',
#  'AAGCATGAGTAACGAG-1',
#  'AAGCATGAGTAAGTGG-1',
#  'AAGCATGAGTATCGCG-1',
#  'AAGCATGAGTTAGCCG-1',
#  'AAGCCACGTAGACAAA-1',
#  'AAGCCACGTCGCGCAA-1',
#  'AAGCCACGTTGTAAAC-1',
#  'AAGCCACGTTTCAGGA-1',
#  'AAGCCTCCACAATTAC-1',
#  'AAGCCTCCACGGTACT-1',
#  'AAGCCTCCACGTAAGG-1',
#  'AAGCCTCCAGGTTATT-1',
#  'AAGCCTGTCATGCCTC-1',
#  'AAGCCTGTCATTGACA-1',
#  'AAGCCTGTCATTTGCT-1',
#  'AAGCCTGTCCAACTGG-1',
#  'AAGCCTGTCCTAATTC-1',
#  'AAGCCTGTCGCATCCT-1',
#  'AAGCCTGTCTCACATT-1',
#  'AAGCCTGTCTTGACCC-1',
#  'AAGCCTTAGTCATTGA-1',
#  'AAGCGAATCCAAGTTA-1',
#  'AAGCGAATCGACAAAG-1',
#  'AAGCGAATCGCACAAT-1',
#  'AAGCGAATCGCTTCTA-1',
#  'AAGCGAGGTAATCGCA-1',
#  'AAGCGAGGTTCACCCA-1',
#  'AAGCGAGGTTCGCGCT-1',
#  'AAGCGCTGTAAGCTTG-1',
#  'AAGCGCTGTGGTTATG-1',
#  'AAGCGCTGTTAGTGAT-1',
#  'AAGCGCTGTTGGTGAC-1',
#  'AAGCGGGTCTCCATGC-1',
#  'AAGCGGGTCTGCAAGT-1',
#  'AAGCGTTTCCTTCAAT-1',
#  'AAGCTAGAGAGAGCCG-1',
#  'AAGCTAGAGGTTAGAG-1',
#  'AAGCTATGTCATGCCC-1',
#  'AAGCTATGTTCGCTTG-1',
#  'AAGCTCCCAGGTTACC-1',
#  'AAGCTTGGTCACAGCG-1',
#  'AAGCTTGGTCGTTACT-1',
#  'AAGCTTGGTGCTGTAA-1',
#  'AAGGAAGCAACCCTAA-1',
#  'AAGGAAGCAATTGAAG-1',
#  'AAGGAAGCACTGGCTG-1',
#  'AAGGAAGCACTTACAG-1',
#  'AAGGAAGCAGGAACTG-1',
#  'AAGGAAGCATATAACC-1',
#  'AAGGATCCAATTAGGA-1',
#  'AAGGATCCACTGACCG-1',
#  'AAGGATCCAGTAGGTG-1',
#  'AAGGATCCATTATCCC-1',
#  'AAGGATGTCACAGCGC-1',
#  'AAGGATGTCTAGCTTT-1',
#  'AAGGATTAGCGTGCAC-1',
#  'AAGGATTAGGTATTGC-1',
#  'AAGGCCCTCACCTGTC-1',
#  'AAGGCCCTCATGTTTC-1',
#  'AAGGCCCTCCCTCAAC-1',
#  'AAGGCCCTCGACCTGA-1',
#  'AAGGCCCTCGAGCAAA-1',
#  'AAGGCCCTCGCTAAGT-1',
#  'AAGGTATAGCACTTGG-1',
#  'AAGGTATAGGTCCTGA-1',
#  'AAGGTCAAGCCAGGTC-1',
#  'AAGGTCAAGGAAGCAC-1',
#  'AAGGTCAAGGAGGGTT-1',
#  'AAGGTCAAGGGCCATC-1',
#  'AAGTAGCCATAAGGAC-1',
#  'AAGTCTATCAAAGGCA-1',
#  'AAGTCTATCCCTGATC-1',
#  'AAGTCTATCCGTGACA-1',
#  'AAGTCTATCGCATCCT-1',
#  'AAGTGAAGTAAAGCAA-1',
#  'AAGTGAAGTAGGATCC-1',
#  'AAGTGAAGTCAAGTGC-1',
#  'AAGTGAAGTCCGCTGT-1',
#  'AAGTGAAGTCTAACCT-1',
#  'AAGTGAAGTGAACAAA-1',
#  'AAGTGAAGTGTGTGGT-1',
#  'AAGTGAAGTTCCTGTG-1',
#  'AAGTGAAGTTGCGGAT-1',
#  'AAGTGAAGTTGGTTCT-1',
#  'AAGTGAAGTTTATGGG-1',
#  'AAGTGCAAGCACAGGG-1',
#  'AAGTGCAAGCGCCTAA-1',
#  'AAGTGCAAGCTATGAC-1',
#  'AAGTGCAAGGAAACTG-1',
#  'AAGTGCAAGGATCACT-1',
#  'AAGTGTTGTAGTTAAC-1',
#  'AAGTGTTGTGGGTACT-1',
#  'AAGTGTTGTTAGCCAA-1',
#  'AAGTTACGTCGTAATG-1',
#  'AAGTTACGTGCATTTC-1',
#  'AAGTTACGTGTTTCAC-1',
#  'AAGTTAGCAATTAGCT-1',
#  'AAGTTAGCACGTAAGG-1',
#  'AAGTTAGCAGGAAGCC-1',
#  'AAGTTAGCATACCCGG-1',
#  'AAGTTTGTCCAAGTTA-1',
#  'AATAACCGTCGTTACT-1',
#  'AATAACCGTGCAATAT-1',
#  'AATAACCGTTTGCGAA-1',
#  'AATACCGGTCTCACTG-1',
#  'AATAGAGGTCCGTAGG-1',
#  'AATAGAGGTCCGTGAG-1',
#  'AATAGAGGTTAGAGGG-1',
#  'AATAGAGGTTCCTGAT-1',
#  'AATAGAGGTTGGTTAG-1',
#  'AATAGAGGTTTGAGCA-1',
#  'AATAGCTGTGAGAAAC-1',
#  'AATAGCTGTTTGTTGC-1',
#  'AATATCCCAAGGAATC-1',
#  'AATATCCCAATAGCAA-1',
#  'AATATCCCACCAGCAT-1',
#  'AATATCCCAGCCAGAA-1',
#  'AATATCCCATCATGTG-1',
#  'AATCAGGAGAAAGCAT-1',
#  'AATCAGGAGCTGGAAA-1',
#  'AATCAGGAGGAACGCG-1',
#  'AATCAGGAGGCTGGCT-1',
#  'AATCAGGAGGTTTACA-1',
#  'AATCAGGAGTTAGTTG-1',
#  'AATCATCCACGAACAG-1',
#  'AATCATCCAGCAAATA-1',
#  'AATCATCCAGGTTCAC-1',
#  'AATCATGTCAAACACC-1',
#  'AATCATGTCCAAACAC-1',
#  'AATCATGTCCCTGACT-1',
#  'AATCATGTCTTGCATT-1',
#  'AATCCATCAAACCCTA-1',
#  'AATCCATCACATAACT-1',
#  'AATCCATCATAAGTCT-1',
#  'AATCCATCATCCATCT-1',
#  'AATCCCTGTACCGTTT-1',
#  'AATCCCTGTAGGATTT-1',
#  'AATCCCTGTATCTGGA-1',
#  'AATCCCTGTCTTGCAT-1',
#  'AATCCCTGTTTGGGTA-1',
#  'AATCCGTAGCCTGAGC-1',
#  'AATCCGTAGCCTGGTA-1',
#  'AATCCGTAGGAAGCTA-1',
#  'AATCCTAAGATACTTG-1',
#  'AATCCTAAGATTCCTT-1',
#  'AATCCTAAGGGATGCG-1',
#  'AATCGCCCATAGCAGG-1',
#  'AATCGCCCATGTCAAT-1',
#  'AATCGCCCATTATGGT-1',
#  'AATCTCAAGCCTGGTA-1',
#  'AATCTCAAGCGAGCGA-1',
#  'AATCTCAAGCTCATAA-1',
#  'AATCTCAAGCTCCCTG-1',
#  'AATCTCAAGGCTATGT-1',
#  'AATCTTGAGCGGATTT-1',
#  'AATCTTGAGCTATTGA-1',
#  'AATCTTGAGCTCCCTG-1',
#  'AATCTTGAGGTGCTGC-1',
#  'AATCTTGAGTTTGCGG-1',
#  'AATGAAGGTGCTTAGA-1',
#  'AATGAAGGTTAAGGCC-1',
#  'AATGCAACAACTAGCC-1',
#  'AATGCAACAAGCTACC-1',
#  'AATGCAACACCGGTAT-1',
#  'AATGCAACACCTCACC-1',
#  'AATGCAACACGAACAG-1',
#  'AATGCATGTCATCAAG-1',
#  'AATGCATGTCATGCAA-1',
#  'AATGCATGTGGATTAT-1',
#  'AATGCATGTTACCTGT-1',
#  'AATGCATGTTGCCTCA-1',
#  'AATGCATGTTTGCAGA-1',
#  'AATGCATGTTTGTGGA-1',
#  'AATGCGCGTAGGATTT-1',
#  'AATGCGCGTCATAACG-1',
#  'AATGCGCGTCCTTCTC-1',
#  'AATGCGCGTGAGACTC-1',
#  'AATGCGCGTTTAACCC-1',
#  'AATGCGCGTTTGGGCG-1',
#  'AATGGCGCAAAGCCTC-1',
#  'AATGGCGCAAGGAATC-1',
#  'AATGGCGCATGCATAT-1',
#  'AATGGCGCATGTTGCA-1',
#  'AATGTCATCAGCAAGA-1',
#  'AATGTCATCTTTAGGA-1',
#  'AATGTCCAGAAAGCAT-1',
#  'AATGTCCAGCTGTAAC-1',
#  'AATTACCCAAACCTAT-1',
#  'AATTACCCACAGGAAT-1',
#  'AATTACCCACGTAATT-1',
#  'AATTACCCAGCCAGTT-1',
#  'AATTACCCAGGCCATT-1',
#  'AATTACCCAGTTAGCC-1',
#  'AATTACCCATGCTTAG-1',
#  'AATTAGCGTGGTTCTT-1',
#  'AATTAGCGTGTTGTAG-1',
#  'AATTAGGCAAACCCTA-1',
#  'AATTAGGCAAACCTAT-1',
#  'AATTAGGCAATAGTCT-1',
#  'AATTAGGCAATTATGC-1',
#  'AATTAGGCAATTGCGC-1',
#  'AATTAGGCAGGCTGTT-1',
#  'AATTAGGCAGGTTTGC-1',
#  'AATTAGGCATTTGCTC-1',
#  'AATTCGTCACAGAAAC-1',
#  'AATTCGTCACTCAACA-1',
#  'AATTCGTCATCAATCG-1',
#  'AATTCGTCATGTCAGC-1',
#  'AATTGACGTAATCACG-1',
#  'AATTGACGTCACGGAT-1',
#  'AATTGACGTCGACTCC-1',
#  'AATTGACGTCTTTGAC-1',
#  'AATTGACGTGATGGCT-1',
#  'AATTGACGTGGCTTCC-1',
#  'AATTGACGTTAGCAGC-1',
#  'AATTGCCAGGTTAGAG-1',
#  'AATTGCTCAAAGCGGC-1',
#  'AATTGCTCAGTCTAGC-1',
#  'AATTGCTCATCGCTCC-1',
#  'AATTGGACAAGCTTAT-1',
#  'AATTGGACAGTTTCTC-1',
#  'AATTGGGAGGAACACA-1',
#  'AATTGGGAGGCGTAAA-1',
#  'AATTGGGAGTTTGTCT-1',
#  'AATTGTGTCAAAGGCA-1',
#  'AATTGTGTCACGTTAA-1',
#  'AATTGTGTCATAACGC-1',
#  'AATTGTGTCCGTTATT-1',
#  'AATTGTGTCGGTACGC-1',
#  'AATTGTGTCGTTCACC-1',
#  'AATTTCCTCAATTACG-1',
#  'AATTTCCTCATTACGA-1',
#  'AATTTCCTCCTGCGAA-1',
#  'AATTTCCTCTAATCTC-1',
#  'AATTTCCTCTACCTCA-1',
#  'AATTTCCTCTTGTTCG-1',
#  'AATTTGCCAAGGTATA-1',
#  'AATTTGCCAATAACGA-1',
#  'AATTTGCCACAATGTT-1',
#  'AATTTGCCAGCACCAT-1',
#  'AATTTGCCAGGATGGC-1',
#  'AATTTGCCAGGCATGA-1',
#  'AATTTGCCATATAACC-1',
#  'AATTTGCCATTGTGTG-1',
#  'AATTTGGTCACCGGTA-1',
#  'ACAAACTGTACCTTAC-1',
#  'ACAAACTGTACGATTG-1',
#  'ACAAACTGTGGTTCTT-1',
#  'ACAAACTGTTAGAGGG-1',
#  'ACAAAGGTCAATAGCC-1',
#  'ACAAAGGTCGAGCTAT-1',
#  'ACAAAGGTCGTGCCTT-1',
#  'ACAACAACAGAGGCTA-1',
#  'ACAACACTCACACAGT-1',
#  'ACAACACTCATTACGA-1',
#  'ACAACAGAGCACTAAC-1',
#  'ACAACAGAGCTATTGA-1',
#  'ACAACAGAGTAACTCA-1',
#  'ACAACAGAGTTTAACG-1',
#  'ACAACATGTAAAGCAA-1',
#  'ACAACATGTAAAGCGG-1',
#  'ACAACATGTAAATTGC-1',
#  'ACAACATGTGCATTAG-1',
#  'ACAACATGTTCGCGCT-1',
#  'ACAACATGTTGCTGGG-1',
#  'ACACAATGTGCGCAAT-1',
#  'ACACAATGTTCAAGAT-1',
#  'ACACCTTGTAGCTGGT-1',
#  'ACACCTTGTCACAGCG-1',
#  'ACACCTTGTGCGCGTA-1',
#  'ACACCTTGTTAACAGT-1',
#  'ACACGGACAAGCGAGC-1',
#  'ACACGGACACCATATG-1',
#  'ACACGGACAGCTCATA-1',
#  'ACACGGACAGCTTACA-1',
#  'ACACGGACAGGTTATT-1',
#  'ACACGGACATAGACCC-1',
#  'ACACGGACATCCCTCA-1',
#  'ACACGGACATGCTCCC-1',
#  'ACACTAATCAACAAGG-1',
#  'ACACTAATCGCACACA-1',
#  'ACACTAATCGCTAGTG-1',
#  'ACACTAATCGGGCCAT-1',
#  'ACACTAATCTAACCAA-1',
#  'ACACTAATCTAACCTT-1',
#  'ACACTAGGTCTTGCAT-1',
#  'ACACTAGGTGACATAT-1',
#  'ACACTAGGTTAACAGT-1',
#  'ACACTAGGTTTACTTG-1',
#  'ACACTTAAGCACTAAC-1',
#  'ACACTTAAGCTTGCTC-1',
#  'ACACTTGCACACCAAC-1',
#  'ACACTTGCACCAAAGG-1',
#  'ACACTTGCATCCAGGT-1',
#  'ACACTTGCATCCCTCA-1',
#  'ACAGCCGGTAAGGTTT-1',
#  'ACAGCCGGTATTTGCC-1',
#  'ACAGCCGGTCCGCTGT-1',
#  'ACAGCCGGTTAAATGC-1',
#  'ACAGCCGGTTTAAAGC-1',
#  'ACAGCGCTCATGGTGT-1',
#  'ACAGCGCTCCTGAATA-1',
#  'ACAGCGCTCTAATCAG-1',
#  'ACAGGAATCAAATCGC-1',
#  'ACAGGAATCATCCTGC-1',
#  'ACAGGAATCCTTCTAG-1',
#  'ACAGGAATCGTTCACC-1',
#  'ACAGGAATCTAAGGAG-1',
#  'ACAGGAATCTGGCTTC-1',
#  'ACAGGATCAAACATAG-1',
#  'ACAGGATCAAACCCTA-1',
#  'ACAGGATCACCTCACC-1',
#  'ACAGGATCACTTAACG-1',
#  'ACAGGCTGTGATGAAA-1',
#  'ACAGGCTGTGTGCAAC-1',
#  'ACAGGCTGTTACGCAA-1',
#  'ACAGGTAAGGATTGAG-1',
#  'ACAGGTAAGTTAGAGG-1',
#  'ACAGTATGTAACGGGA-1',
#  'ACATAGCTCACGCGGT-1',
#  'ACATAGCTCGCTATGG-1',
#  'ACATAGCTCGTTCACC-1',
#  'ACATAGCTCTTGGACG-1',
#  'ACATCAATCCCTGATC-1',
#  'ACATCAATCGTTACTT-1',
#  'ACATCATCAATACTGT-1',
#  'ACATCATCACTGGCTG-1',
#  'ACATCATCAGCAGGTA-1',
#  'ACATCATCATCCTGAA-1',
#  'ACATCATCATGTTGGC-1',
#  'ACATTAGTCATAATCG-1',
#  'ACATTAGTCATTAGCA-1',
#  'ACATTAGTCCAACTGG-1',
#  'ACATTAGTCGAGCAAA-1',
#  'ACATTGCAGCCGCTTT-1',
#  'ACATTGCAGGATCACT-1',
#  'ACCAAACTCATAAGCC-1',
#  'ACCAAACTCCCGCAAA-1',
#  'ACCAAACTCCCTCATA-1',
#  'ACCAAACTCGAAGTGA-1',
#  'ACCAAACTCGCAACAT-1',
#  'ACCAAACTCGCATCCT-1',
#  'ACCAAACTCGTAATCA-1',
#  'ACCAAACTCGTTAGTA-1',
#  'ACCAAACTCTAAGTCA-1',
#  'ACCAAGCGTAAGGTTT-1',
#  'ACCAAGCGTCACACCC-1',
#  'ACCAAGCGTCAGTAAT-1',
#  'ACCAAGCGTGATCAGC-1',
#  'ACCAAGCGTGATGGCT-1',
#  'ACCAAGCGTTAGCCAA-1',
#  'ACCAAGTTCCGGTATG-1',
#  'ACCAAGTTCCTCCATA-1',
#  'ACCAAGTTCCTTAGGG-1',
#  'ACCAATATCCCTCACG-1',
#  'ACCAATATCTAAATCG-1',
#  'ACCAATATCTTAAGTG-1',
#  'ACCACACCAGGTATTT-1',
#  'ACCACATAGCAAGGTA-1',
#  'ACCACATAGCCTGATG-1',
#  'ACCACATAGTAACCCG-1',
#  'ACCACATAGTCGCTAG-1',
#  'ACCAGCTCAATTATGC-1',
#  'ACCAGCTCAGAATGAC-1',
#  'ACCAGCTCAGCAATAA-1',
#  'ACCAGCTCAGTTTGTG-1',
#  'ACCAGGACACCACAAC-1',
#  'ACCAGGACATAGACCC-1',
#  'ACCAGGACATGCAACC-1',
#  'ACCAGGACATTCCTCG-1',
#  'ACCAGGCTCAATACGC-1',
#  'ACCAGGCTCCTAATTC-1',
#  'ACCAGGCTCTCGCCTG-1',
#  'ACCAGGCTCTTGTTCG-1',
#  'ACCAGGGAGAAAGGAA-1',
#  'ACCAGGGAGAACCTAC-1',
#  'ACCAGGGAGCTTCTCA-1',
#  'ACCAGGGAGCTTTGTT-1',
#  'ACCAGGGAGGGTTATC-1',
#  'ACCAGGGAGGTATTGC-1',
#  'ACCATAATCAGTATTG-1',
#  'ACCATAATCCTAGTTT-1',
#  'ACCATAATCTTGCATT-1',
#  'ACCATTAAGCCTTAAA-1',
#  'ACCATTAAGGAAACTG-1',
#  'ACCCAACCAAGGTCGA-1',
#  'ACCCAGGGTATTGGAT-1',
#  'ACCCAGGGTGTGTGGT-1',
#  'ACCCAGGGTTCCTGAT-1',
#  'ACCCAGGGTTCGGGAT-1',
#  'ACCCAGGGTTGGGTTA-1',
#  'ACCCGGTAGACTTATG-1',
#  'ACCCGGTAGCGATACT-1',
#  'ACCCGGTAGGCTATGT-1',
#  'ACCCGGTAGGCTGTGC-1',
#  'ACCCGGTAGGTCAAAG-1',
#  'ACCCGGTAGTATCGCG-1',
#  'ACCCGTAAGGCTGTCA-1',
#  'ACCCTCCCATTCAGCA-1',
#  'ACCCTGTTCATGTTTC-1',
#  'ACCCTGTTCCTAAATG-1',
#  'ACCCTGTTCGGCTAGC-1',
#  'ACCCTGTTCTAGCTTT-1',
#  'ACCGAAGCAGCAATAA-1',
#  'ACCGAAGCAGGAACTG-1',
#  'ACCGAAGCAGGTCCTG-1',
#  'ACCGCAATCAATCTAG-1',
#  'ACCGCAATCATAATCG-1',
#  'ACCGCAATCCTCATGC-1',
#  'ACCGCAATCGCAACAT-1',
#  'ACCGGCTAGCACTTGG-1',
#  'ACCGGCTAGGATCACT-1',
#  'ACCTAAATCAGGAAGC-1',
#  'ACCTAAATCATTTAGG-1',
#  'ACCTAAATCCAGCACA-1',
#  'ACCTAAATCCGCAAGC-1',
#  'ACCTAAATCCTCCCTC-1',
#  'ACCTAAGGTGTGAGGA-1',
#  'ACCTAAGGTTGTTGGA-1',
#  'ACCTACCTCACAGCCA-1',
#  'ACCTACCTCGCAATCG-1',
#  'ACCTACCTCGTAATCA-1',
#  'ACCTACCTCGTGCCTT-1',
#  'ACCTACCTCTTGCTAT-1',
#  'ACCTCACTCAAAGGCA-1',
#  'ACCTCACTCAGGTTTA-1',
#  'ACCTCACTCGATTTGA-1',
#  'ACCTGGATCAATGAGG-1',
#  'ACCTGGATCACTAGGT-1',
#  'ACCTGGATCTGCAACG-1',
#  'ACCTGGATCTTACTCG-1',
#  'ACCTGGTCACCGTTCC-1',
#  'ACCTGGTCACCTGCCT-1',
#  'ACCTGGTCAGGAACTG-1',
#  'ACCTGGTCAGGACCTT-1',
#  'ACCTGGTCATGCTCCC-1',
#  'ACCTGTTGTGCGCATG-1',
#  'ACCTTCATCACAGACT-1',
#  'ACCTTCATCCAGCACA-1',
#  'ACCTTCATCCTCACAC-1',
#  'ACCTTCATCCTTCAAT-1',
#  'ACCTTCATCCTTTACG-1',
#  'ACCTTCATCGGTTACG-1',
#  'ACCTTCATCTAGCTTT-1',
#  'ACCTTCATCTCACATT-1',
#  'ACCTTCATCTCACTAT-1',
#  'ACCTTCATCTTTGTAC-1',
#  'ACCTTCCAGTGCACGC-1',
#  'ACCTTGCTCAACAAGG-1',
#  'ACCTTGCTCAGTGAAG-1',
#  'ACCTTGCTCCAGGTCA-1',
#  'ACCTTGCTCCCTGGTT-1',
#  'ACCTTGCTCGCAACAT-1',
#  'ACCTTGCTCTTGCAGG-1',
#  'ACCTTGTGTCAATACG-1',
#  'ACGAACAAGGCGAATA-1',
#  'ACGAACAAGGCTTAAC-1',
#  'ACGAACAAGTAGGATG-1',
#  'ACGAAGTCAAATGCCC-1',
#  'ACGAAGTCAACTGGCT-1',
#  'ACGAAGTCAATCGCAC-1',
#  'ACGAAGTCACTAAGCC-1',
#  'ACGAAGTCAGCTAATT-1',
#  'ACGAAGTCATAGGCGA-1',
#  'ACGAATCTCAGGCCTA-1',
#  'ACGAATCTCATCCTAT-1',
#  'ACGAATCTCCCGAACA-1',
#  'ACGAATCTCCCGCCTA-1',
#  'ACGACAAAGCAAGGTA-1',
#  'ACGACAAAGGCGAAAC-1',
#  'ACGACTTAGCACAGAA-1',
#  'ACGACTTAGGGCTTTG-1',
#  'ACGACTTAGGTTTACA-1',
#  'ACGACTTAGTGAACCT-1',
#  'ACGACTTAGTTGTCTT-1',
#  'ACGAGTAAGAACCTAC-1',
#  'ACGAGTAAGATTCCTT-1',
#  'ACGAGTAAGCAAGACA-1',
#  'ACGATTCAGACAGGCG-1',
#  'ACGATTCAGCTGGAAA-1',
#  'ACGATTCAGGAACCGG-1',
#  'ACGATTCAGGCCATCA-1',
#  'ACGATTCAGTAACTCA-1',
#  'ACGATTCAGTCCTTCA-1',
#  'ACGATTCAGTTCCTCA-1',
#  'ACGCAAGCAAGGTCGA-1',
#  'ACGCAAGCAGGCCTTG-1',
#  'ACGCAAGCATCCTGAA-1',
#  'ACGCACGGTAATCGCA-1',
#  'ACGCACGGTTAAGCTG-1',
#  'ACGCACGGTTGGCGTG-1',
#  'ACGCACGGTTTACGTC-1',
#  'ACGCCACAGAGCCGCT-1',
#  'ACGCCACAGGAGCAAC-1',
#  'ACGCCTAAGGAGTAAT-1',
#  'ACGCCTAAGGCTATGT-1',
#  'ACGCCTTTCCAGGAAA-1',
#  'ACGCTTGAGAGCCGCT-1',
#  'ACGCTTGAGCACAGAA-1',
#  'ACGCTTGAGTGGCGGA-1',
#  'ACGGGAAGTGGGTACT-1',
#  'ACGGGAAGTGGTTAGC-1',
#  'ACGGGAAGTGTTAGCA-1',
#  'ACGGGAAGTTACCTGT-1',
#  'ACGGTACGTCCTAACT-1',
#  'ACGGTACGTGCGCATG-1',
#  'ACGGTACGTGCTCCAC-1',
#  'ACGGTACGTTAAGTGT-1',
#  'ACGGTACGTTGGTTCT-1',
#  'ACGGTTAGTAAACAAG-1',
#  'ACGGTTAGTCTAACCT-1',
#  'ACGGTTAGTGCAATGC-1',
#  'ACGGTTAGTGCGCAAT-1',
#  'ACGGTTAGTGTAATAC-1',
#  'ACGGTTTAGAGGAAGG-1',
#  'ACGGTTTAGCGAGGTG-1',
#  'ACGGTTTAGCGATACT-1',
#  'ACGGTTTAGCGCCTAA-1',
#  'ACGGTTTAGCGGATTT-1',
#  'ACGGTTTAGCTAAGTC-1',
#  'ACGTACCCAAGGTACG-1',
#  'ACGTACCCACGAATTT-1',
#  'ACGTACCCATCTAGCA-1',
#  'ACGTACCCATGACTAT-1',
#  'ACGTCAAGTCAAGACC-1',
#  'ACGTCAAGTCCTTTAA-1',
#  'ACGTCAAGTCGCGCAA-1',
#  'ACGTCAAGTGTCCAAA-1',
#  'ACGTCAAGTTAATGAC-1',
#  'ACGTCAAGTTCCATTA-1',
#  'ACGTCAAGTTCCTCCT-1',
#  'ACGTCAAGTTGCACGG-1',
#  'ACGTCAAGTTGCAGTA-1',
#  'ACGTCCAAGCTCATAA-1',
#  'ACGTCCAAGGCCATCA-1',
#  'ACGTCCAAGTAGCGGG-1',
#  'ACGTCCAAGTGTGATC-1',
#  'ACGTCCTTCCACCTGT-1',
#  'ACGTCCTTCCCGAAGC-1',
#  'ACGTCCTTCGATCAGT-1',
#  'ACGTCCTTCGTAATCA-1',
#  'ACGTTACAGACACTTA-1',
#  'ACGTTACAGACAGGTA-1',
#  'ACGTTACAGAGGAGTC-1',
#  'ACGTTACAGGTATTGC-1',
#  'ACGTTACAGGTGAGAC-1',
#  'ACGTTGTAGACAACGA-1',
#  'ACGTTGTAGCGGGCAA-1',
#  'ACGTTGTAGGACAACA-1',
#  'ACGTTGTAGGCACAGG-1',
#  'ACTAAAGCAAGCTTAT-1',
#  'ACTAAAGCACTAGCGT-1',
#  'ACTAAAGCAGGCGAGT-1',
#  'ACTAAAGCAGGTTTGC-1',
#  'ACTAACCAGCCTGACA-1',
#  'ACTAACCAGGCCGGAA-1',
#  'ACTAACCAGGGCCATC-1',
#  'ACTAACGGTACTAAAC-1',
#  'ACTAACGGTTGCGGAT-1',
#  'ACTAACGGTTGTAACG-1',
#  'ACTAACGGTTTGTGGA-1',
#  'ACTAACTCAAATATCC-1',
#  'ACTAACTCAAGGTCCT-1',
#  'ACTAACTCACAGACTC-1',
#  'ACTAACTCACCCTCAC-1',
#  'ACTAACTCAGCACCAT-1',
#  'ACTAACTCAGCTCATA-1',
#  'ACTAACTCATAATCAC-1',
#  'ACTAACTCATAGCTTG-1',
#  'ACTAATCCACCCACCT-1',
#  'ACTAATCCAGGACACA-1',
#  'ACTAATCCATCTTGAG-1',
#  'ACTAGGCGTAGACAAA-1',
#  'ACTAGGCGTGATCAGC-1',
#  'ACTAGGCGTGCTGTAA-1',
#  'ACTAGGCGTGTTCCCA-1',
#  'ACTAGGCGTTACTTCA-1',
#  'ACTAGGCGTTCAAGCA-1',
#  'ACTATCCGTGAAGCCT-1',
#  'ACTATCCGTGTGCACG-1',
#  'ACTATGTCAACACCTA-1',
#  'ACTATGTCAATTTAGC-1',
#  'ACTATGTCACCAGGTT-1',
#  'ACTATGTCAGGCTAAG-1',
#  'ACTCACCTCAAACCTA-1',
#  'ACTCACCTCATCCTGC-1',
#  'ACTCACCTCATGGCTG-1',
#  'ACTCACCTCCTCCCTC-1',
#  'ACTCACCTCCTTAAGA-1',
#  'ACTCACCTCTGTGCCT-1',
#  'ACTCACTGTAGGTTGC-1',
#  'ACTCACTGTAGTTAAC-1',
#  'ACTCACTGTCATAACG-1',
#  'ACTCACTGTCTATCGT-1',
#  'ACTCAGTAGATACTTG-1',
#  'ACTCAGTAGGAAACTG-1',
#  'ACTCAGTAGGTCCACA-1',
#  'ACTCAGTAGTCTATGA-1',
#  'ACTCAGTAGTCTTGAA-1',
#  'ACTCAGTAGTTATCTC-1',
#  'ACTCCTCAGCATTATG-1',
#  'ACTCCTCAGGATGATG-1',
#  'ACTCGCGCACCTGTAA-1',
#  'ACTCGCGCAGCATTAT-1',
#  'ACTCGCGCAGCTTAGC-1',
#  'ACTCGCTTCCGCCTAT-1',
#  'ACTCGCTTCCGGGACT-1',
#  'ACTCGCTTCCTCGATC-1',
#  'ACTCGCTTCTCACATT-1',
#  'ACTGAAACAAGTCGCT-1',
#  'ACTGAAACAGCAACCT-1',
#  'ACTGAATGTCTCACTG-1',
#  'ACTGAATGTGTTAAAC-1',
#  'ACTGAATGTTAGCATG-1',
#  'ACTGAATGTTCGGTAA-1',
#  'ACTTACAAGATAAAGC-1',
#  'ACTTACAAGGCTGTCA-1',
#  'ACTTACAAGTTAACCA-1',
#  'ACTTACTTCGGTACGC-1',
#  'ACTTACTTCGTTCACC-1',
#  'ACTTAGGGTAAGCTTG-1',
#  'ACTTAGGGTCCTTAGT-1',
#  'ACTTAGGGTTATCCTA-1',
#  'ACTTAGGGTTGAGGTC-1',
#  'ACTTAGGGTTGCACAA-1',
#  'ACTTAGGGTTTGGCTT-1',
#  'ACTTAGTCAGGCTGTT-1',
#  'ACTTAGTCAGTAGCCT-1',
#  'ACTTAGTCATCCATCT-1',
#  'ACTTAGTCATTAGCGC-1',
#  'ACTTATCTCAAACTCA-1',
#  'ACTTATCTCATGAGCT-1',
#  'ACTTATCTCGGTCAGC-1',
#  'ACTTATCTCGTTATAG-1',
#  'ACTTATGAGCCTGAGC-1',
#  'ACTTATGAGGTTTGAC-1',
#  'ACTTATGAGTCACCTC-1',
#  'ACTTCGCTCATGTGGT-1',
#  'ACTTCGCTCTCAATTC-1',
#  'ACTTGAATCATGACCG-1',
#  'ACTTGAATCCTTAGTT-1',
#  'ACTTGCACAATAAGCA-1',
#  'ACTTGCACACGAACAG-1',
#  'ACTTGTAAGCTAAGTC-1',
#  'ACTTGTAAGTCACCAG-1',
#  'ACTTGTCGTAATCGGC-1',
#  'ACTTGTCGTGGGTACT-1',
#  'ACTTTGTTCACTTTAC-1',
#  'ACTTTGTTCTTTGACT-1',
#  'AGAAACCCAACAGGTG-1',
#  'AGAAACCCAAGATTCT-1',
#  'AGAAACCCAATTGAGA-1',
#  'AGAAACCCAGGGAGGA-1',
#  'AGAAACCCAGTTATCG-1',
#  'AGAAACCCATAAGTCT-1',
#  'AGAAACTAGCTTCCCG-1',
#  'AGAAACTAGGGACCTC-1',
#  'AGAAAGGCAATAAGCA-1',
#  'AGAAAGGCAGGACACA-1',
#  'AGAAAGGCATGACTAT-1',
#  'AGAAAGGCATGTTGCA-1',
#  'AGAAAGGCATGTTGGC-1',
#  'AGAAAGGCATTGACAT-1',
#  'AGAACAAGTAATGGCC-1',
#  'AGAACAAGTCACACCC-1',
#  'AGAACCAAGCTAAGTC-1',
#  'AGAACCAAGGAACCAA-1',
#  'AGAACCAAGGCTAATC-1',
#  'AGAACCAAGGTGAAGC-1',
#  'AGAACCGCAAGTCGCT-1',
#  'AGAACCGCAGGACCTT-1',
#  'AGAACCGCATTGTTGG-1',
#  'AGAAGGTGTCTATCGT-1',
#  'AGAAGGTGTTAGGTGC-1',
#  'AGAATCGAGCAGCTCA-1',
#  'AGAATCGAGGCGTAAA-1',
#  'AGAATCGAGGCTGGCT-1',
#  'AGACAATAGAAAGCAT-1',
#  'AGACAATAGAATGACG-1',
#  'AGACACGCATTGCGGT-1',
#  'AGACCCGGTAGTCAAT-1',
#  'AGACCCGGTCCTTTAA-1',
#  'AGACCCGGTGAAGCCT-1',
#  'AGACCCGGTGAGAAAC-1',
#  'AGACCCGGTGATGATT-1',
#  'AGACCCGGTGTTTCAC-1',
#  'AGACCCGGTTGGTTGA-1',
#  'AGACTATGTCAATACG-1',
#  'AGACTATGTCTAGCTT-1',
#  'AGACTATGTGTTCCCA-1',
#  'AGAGAAGCACTTCATC-1',
#  'AGAGAAGCAGGTCCTG-1',
#  'AGAGAAGCAGGTTAAA-1',
#  'AGAGAAGCAGTATGTT-1',
#  'AGAGAAGCATTGTGCA-1',
#  'AGAGAGGAGACTATTG-1',
#  'AGAGAGGAGGAGCATA-1',
#  'AGAGAGGAGTAAAGGT-1',
#  'AGAGAGGAGTTATCTC-1',
#  'AGAGAGGAGTTCCTCA-1',
#  'AGAGAGGAGTTTGGGT-1',
#  'AGAGATTAGAAACTGG-1',
#  'AGAGATTAGCCTCTGT-1',
#  'AGAGATTAGTTAGCTA-1',
#  'AGAGGAACAGGACCTT-1',
#  'AGAGGAACATGCTCCC-1',
#  'AGAGGATGTAATCGTG-1',
#  'AGAGGATGTGTCACGG-1',
#  'AGAGGATGTTGGCCGA-1',
#  'AGAGGATGTTTGAGCA-1',
#  'AGATGAAGTCACAGCG-1',
#  'AGATGAAGTGAACAAA-1',
#  'AGATGAAGTGCACGCA-1',
#  'AGATGAAGTGTTTGCT-1',
#  'AGATGAAGTTGGATCA-1',
#  'AGATGCTTCAGTTCCC-1',
#  'AGCAAATAGAAAGCAT-1',
#  'AGCAAATAGATAAAGC-1',
#  'AGCAAATAGGGTGAAC-1',
#  'AGCAAATAGTGAGCAA-1',
#  'AGCAAATAGTGAGGTA-1',
#  'AGCAACAAGGAGGTTA-1',
#  'AGCAACAAGGCGCACT-1',
#  'AGCAACAAGGCTGTCA-1',
#  'AGCAAGGGTACCGTAA-1',
#  'AGCAAGGGTCCGCTGT-1',
#  'AGCAAGGGTTGTTGTC-1',
#  'AGCAATACAACACTTG-1',
#  'AGCAATACAATCATGT-1',
#  'AGCAATACAATGAAGC-1',
#  'AGCAATACAATGAGGT-1',
#  'AGCAATACAGTTTGGC-1',
#  'AGCAATACATAATCCG-1',
#  'AGCAATACATGAAATG-1',
#  'AGCAATACATTGGGAG-1',
#  'AGCAATTGTCACTCGC-1',
#  'AGCAATTGTCATTGTC-1',
#  'AGCAATTGTGAGGTAG-1',
#  'AGCAATTGTGCTTTAC-1',
#  'AGCAATTGTGGATTAT-1',
#  'AGCAATTGTTTAAAGC-1',
#  'AGCACAGCACTCAACA-1',
#  'AGCACAGCATACCCGG-1',
#  'AGCACTAGTAGCTAAT-1',
#  'AGCACTAGTCCGGTTC-1',
#  'AGCACTAGTGTTGTGA-1',
#  'AGCACTAGTTTGGTTC-1',
#  'AGCACTTAGAGGAGTC-1',
#  'AGCACTTAGCAGGTGG-1',
#  'AGCACTTAGCTATTGA-1',
#  'AGCACTTAGCTCCTTA-1',
#  'AGCACTTAGGATCCGC-1',
#  'AGCACTTAGGCCTTAG-1',
#  'AGCACTTAGTCTTGAA-1',
#  'AGCAGGTAGCTAAGTC-1',
#  ...]

# %%
# Start from fragments file
adata = snap.pp.import_fragments(
    fragment_file=fragment_file,
    chrom_sizes=snap.genome.hg38,
    file=output_file,
    sorted_by_barcode=False,
    whitelist=whitelist,
    n_jobs=n_jobs,
)
adata
# Out:
# AnnData object with n_obs x n_vars = 7503 x 0 backed at 'results/1_qc_metrics/1619MM/1619MM.atac.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito'
#     uns: 'reference_sequences'
#     obsm: 'fragment_paired'

# %%
# Plot fragment size distribution
snap.pl.frag_size_distr(adata, interactive=False)
# Out:
# 2025-03-30 15:34:30 - INFO - Computing fragment size distribution...

# %%
# Compute TSSe scores of individual cells
snap.metrics.tsse(adata, snap.genome.hg38, n_jobs=n_jobs)
adata
# Out:
# AnnData object with n_obs x n_vars = 7503 x 0 backed at 'results/1_qc_metrics/1619MM/1619MM.atac.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#     uns: 'frag_size_distr', 'library_tsse', 'TSS_profile', 'frac_overlap_TSS', 'reference_sequences'
#     obsm: 'fragment_paired'

# %%
# Plot TSSe scores against number of unique fragments for each cell
snap.pl.tsse(adata, interactive=False)

# %%
# Create a cell by bin matrix
snap.pp.add_tile_matrix(adata, n_jobs=n_jobs)
adata
# Out:
# AnnData object with n_obs x n_vars = 7503 x 6062095 backed at 'results/1_qc_metrics/1619MM/1619MM.atac.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#     uns: 'frag_size_distr', 'library_tsse', 'TSS_profile', 'frac_overlap_TSS', 'reference_sequences'
#     obsm: 'fragment_paired'

# %%
# Select variable features (necessary for scrublet)
snap.pp.select_features(adata, blacklist=blacklist_file, n_jobs=n_jobs)
adata
# Out:
# 2025-03-30 15:34:53 - INFO - Selected 497105 features.
# AnnData object with n_obs x n_vars = 7503 x 6062095 backed at 'results/1_qc_metrics/1619MM/1619MM.atac.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#     var: 'count', 'selected'
#     uns: 'frag_size_distr', 'library_tsse', 'TSS_profile', 'frac_overlap_TSS', 'reference_sequences'
#     obsm: 'fragment_paired'

# %%
# Doublet detection
snap.pp.scrublet(adata, n_jobs=n_jobs)
adata
# Out:
# 2025-03-30 15:34:57 - INFO - Simulating doublets...
# 2025-03-30 15:34:57 - INFO - Spectral embedding ...
# 2025-03-30 15:35:32 - INFO - Calculating doublet scores...
# AnnData object with n_obs x n_vars = 7503 x 6062095 backed at 'results/1_qc_metrics/1619MM/1619MM.atac.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse', 'doublet_probability', 'doublet_score'
#     var: 'count', 'selected'
#     uns: 'frag_size_distr', 'library_tsse', 'TSS_profile', 'frac_overlap_TSS', 'scrublet_sim_doublet_score', 'reference_sequences'
#     obsm: 'fragment_paired'

# %%
# Close object (saves to disk)
adata.close()
adata
# Out:
# Closed AnnData object
