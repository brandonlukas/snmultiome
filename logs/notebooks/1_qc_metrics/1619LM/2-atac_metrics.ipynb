# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys;sys.path.extend(['/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12/site-packages', '/home/brandon/code/pingyin/snmultiome/workflow/rules', '/home/brandon/code/pingyin/snmultiome/workflow', '/home/brandon/miniconda3/envs/snapatac2_env/bin', '/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12', '/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12/lib-dynload', '/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12/site-packages', '/home/brandon/.cache/snakemake/snakemake/source-cache/runtime-cache/tmpl3iz42yn/file/home/brandon/code/pingyin/snmultiome/workflow/rules/../notebooks/1_qc_metrics', '/home/brandon/code/pingyin/snmultiome/workflow/rules/../notebooks/1_qc_metrics']);import pickle;from snakemake import script;script.snakemake = pickle.loads(b'\x80\x04\x95\xb0\x06\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c+results/0_initialization/1619LM/1619LM.h5mu\x94\x8cM/home/brandon/data/pingyin/snmultiome/input/1619LM/outs/atac_fragments.tsv.gz\x94\x8cb/home/brandon/data/pingyin/snmultiome/input/1619LM/outs/filtered_feature_bc_matrix/barcodes.tsv.gz\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\tfragments\x94K\x01N\x86\x94\x8c\x08barcodes\x94K\x02N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x16h\x06\x8c\x0eAttributeGuard\x94\x93\x94)\x81\x94}\x94\x8c\x04name\x94h\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sbh\x10h\x0bh\x12h\x0cub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8c,results/1_qc_metrics/1619LM/1619LM.atac.h5ad\x94a}\x94(h\x0e}\x94h\x14]\x94(h\x16h\x17eh\x16h\x19)\x81\x94}\x94h\x1ch\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sbub\x8c\r_params_store\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94\x8c\x1fresources/hg38-blacklist.v2.bed\x94a}\x94(h\x0e}\x94\x8c\tblacklist\x94K\x00N\x86\x94sh\x14]\x94(h\x16h\x17eh\x16h\x19)\x81\x94}\x94h\x1ch\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sbh2h/ub\x8c\r_params_types\x94}\x94\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\x061619LM\x94a}\x94(h\x0e}\x94\x8c\x06sample\x94K\x00N\x86\x94sh\x14]\x94(h\x16h\x17eh\x16h\x19)\x81\x94}\x94h\x1ch\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sb\x8c\x06sample\x94h?ub\x8c\x07threads\x94K\x0c\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x0cK\x01\x8c\x04/tmp\x94e}\x94(h\x0e}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x14]\x94(h\x16h\x17eh\x16h\x19)\x81\x94}\x94h\x1ch\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sbhRK\x0chTK\x01hVhOub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c7logs/notebooks/1_qc_metrics/1619LM/2-atac_metrics.ipynb\x94a}\x94(h\x0e}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x14]\x94(h\x16h\x17eh\x16h\x19)\x81\x94}\x94h\x1ch\x16sbh\x17h\x19)\x81\x94}\x94h\x1ch\x17sbhdhaub\x8c\x06config\x94}\x94(\x8c\x08data_dir\x94\x8c,/home/brandon/data/pingyin/snmultiome/input/\x94\x8c\x0bresults_dir\x94\x8c\x08results/\x94\x8c\x07samples\x94]\x94(\x8c\x061619LM\x94\x8c\x061619MM\x94\x8c\x061633LM\x94\x8c\r1633MM-repeat\x94e\x8c\x03RNA\x94}\x94(\x8c\x10celltypist_model\x94\x8c\x1bHuman_Endometrium_Atlas.pkl\x94\x8c\x02qc\x94}\x94(\x8c\tmin_genes\x94K\xc8\x8c\nmin_counts\x94M\xf4\x01\x8c\rpct_counts_mt\x94K\x05\x8c\x0fpct_counts_ribo\x94K\x05\x8c\rdoublet_score\x94G?\xd3333333\x8c\tmin_cells\x94K\x03uu\x8c\x04ATAC\x94}\x94(\x8c\tblacklist\x94h/\x8c\x02qc\x94}\x94(\x8c\x08min_tsse\x94K\x07\x8c\nmin_counts\x94M\xe8\x03\x8c\tmin_cells\x94K\x03uuu\x8c\x04rule\x94\x8c\x0catac_metrics\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cN/home/brandon/code/pingyin/snmultiome/workflow/rules/../notebooks/1_qc_metrics\x94ub.');del script;from snakemake.logging import logger;from snakemake.script import snakemake;import os; os.chdir(r'/home/brandon/code/pingyin/snmultiome');
######## snakemake preamble end #########

# %% [markdown]
# # Compute ATAC QC metrics

# %%
# Load libraries
import snapatac2 as snap
import pandas as pd
from snakemake.script import snakemake

# %%
# Read input and output paths from Snakemake
fragment_file = snakemake.input["fragments"]
barcodes_file = snakemake.input["barcodes"]
output_file = snakemake.output[0]
n_jobs = snakemake.threads
blacklist_file = snakemake.params.get("blacklist", None)

# %%
# Extract list of barcodes
whitelist = pd.read_csv(barcodes_file, header=None)[0].tolist()
whitelist
# Out:
# ['AAACAGCCAAAGGCCA-1',
#  'AAACAGCCACAAAGCG-1',
#  'AAACAGCCAGATTCAT-1',
#  'AAACAGCCAGGATTAA-1',
#  'AAACATGCAAACCTAT-1',
#  'AAACATGCAAGGACCA-1',
#  'AAACATGCATCATGGC-1',
#  'AAACATGCATGTCAAT-1',
#  'AAACCAACAAACTCAT-1',
#  'AAACCAACAATATGGA-1',
#  'AAACCAACACCAGGTT-1',
#  'AAACCAACACGTGCTG-1',
#  'AAACCAACAGCTACGT-1',
#  'AAACCAACATAAGTTC-1',
#  'AAACCAACATCAGTAT-1',
#  'AAACCAACATCCTAGA-1',
#  'AAACCGAAGCTAATCA-1',
#  'AAACCGAAGGAGGTTA-1',
#  'AAACCGAAGGATTTGC-1',
#  'AAACCGAAGGGTCTAT-1',
#  'AAACCGAAGTACTGGT-1',
#  'AAACCGAAGTTAGCCG-1',
#  'AAACCGCGTCAGTAAT-1',
#  'AAACCGCGTTAAGGTT-1',
#  'AAACCGCGTTCCGGGA-1',
#  'AAACCGCGTTGGATCA-1',
#  'AAACCGGCAATGAGGT-1',
#  'AAACCGGCAATGCGCT-1',
#  'AAACCGGCACCCTCAC-1',
#  'AAACCGGCACGTTACA-1',
#  'AAACCGGCATCATGGC-1',
#  'AAACGCGCAGGCTAGA-1',
#  'AAACGGATCCTAAGGT-1',
#  'AAACGGATCGTTAGTA-1',
#  'AAACGGATCTAACCTT-1',
#  'AAACGTACAATTGAGA-1',
#  'AAACGTACACTAAGCC-1',
#  'AAACGTACATCCATCT-1',
#  'AAACGTACATGACTAT-1',
#  'AAAGCAAGTAACGGGA-1',
#  'AAAGCACCAAGCGAGC-1',
#  'AAAGCACCAGGAATCG-1',
#  'AAAGCACCAGGCTAAG-1',
#  'AAAGCACCAGTTATCG-1',
#  'AAAGCACCATGAATAG-1',
#  'AAAGCACCATGCAACC-1',
#  'AAAGCCCGTAATCCCT-1',
#  'AAAGCCCGTGAGACTC-1',
#  'AAAGCCCGTGGATGTC-1',
#  'AAAGCCCGTTAAGGTT-1',
#  'AAAGCCCGTTAGTACG-1',
#  'AAAGCCGCAGCACGAA-1',
#  'AAAGCGGGTTACAACG-1',
#  'AAAGCGGGTTAGAGGG-1',
#  'AAAGCGGGTTAGCCAA-1',
#  'AAAGCTTGTCAAAGAA-1',
#  'AAAGCTTGTCACGAAC-1',
#  'AAAGGACGTTGCTGGG-1',
#  'AAAGGACGTTTGACCT-1',
#  'AAAGGAGCACATAACT-1',
#  'AAAGGCTCAATAGTCT-1',
#  'AAAGGCTCACAGAAAC-1',
#  'AAAGGCTCACCACAAC-1',
#  'AAAGGCTCACTAAGAA-1',
#  'AAAGGCTCAGAACCGA-1',
#  'AAAGGTTAGACCATAC-1',
#  'AAAGGTTAGCTTAGCG-1',
#  'AAAGGTTAGTGATTCA-1',
#  'AAAGGTTAGTTAACCA-1',
#  'AAATCCGGTGATTACG-1',
#  'AAATCCGGTTAGAGCC-1',
#  'AAATCCGGTTTGTTGC-1',
#  'AAATGCCTCACAGGAA-1',
#  'AAATGCCTCGATTTAG-1',
#  'AAATGCCTCGTAATCA-1',
#  'AAATGCCTCTGCAAGT-1',
#  'AAATGGCCACAGAAAC-1',
#  'AAATGGCCACTCAACA-1',
#  'AAATGGCCAGGATGGC-1',
#  'AAATGGCCAGTTTGGC-1',
#  'AAATGGCCATCAGCAC-1',
#  'AAATGGCCATTGTGAT-1',
#  'AACAAAGGTATTACCC-1',
#  'AACAAAGGTGGGTGAA-1',
#  'AACAAAGGTGTCCTGC-1',
#  'AACAAAGGTGTTGTAG-1',
#  'AACAAAGGTTATCGAG-1',
#  'AACAAGCCAAAGCGCA-1',
#  'AACAAGCCAACCCTCC-1',
#  'AACAAGCCAGTCTAAT-1',
#  'AACAAGCCAGTTTCTC-1',
#  'AACAGATAGACAAAGT-1',
#  'AACAGATAGGAGGTTA-1',
#  'AACAGATAGTAAAGGT-1',
#  'AACAGATAGTAACTCA-1',
#  'AACAGATAGTGAGAGC-1',
#  'AACAGCAAGACAAACG-1',
#  'AACAGCAAGACAGGCG-1',
#  'AACAGCAAGCACAGCC-1',
#  'AACAGCAAGGCTATGT-1',
#  'AACAGCAAGGGTCTAT-1',
#  'AACAGCAAGTCACCAG-1',
#  'AACAGCAAGTTATTCC-1',
#  'AACAGCAAGTTCCTCA-1',
#  'AACAGGATCCCATAGG-1',
#  'AACAGGATCCTACCTA-1',
#  'AACAGGATCCTTCTAG-1',
#  'AACAGGATCGTACCGA-1',
#  'AACATAGCAACCTGGT-1',
#  'AACATAGCAATAATGG-1',
#  'AACATAGCACGAATCC-1',
#  'AACATAGCACGGTACT-1',
#  'AACATAGCACGGTTTA-1',
#  'AACATAGCACGTGCTG-1',
#  'AACATAGCACTATGGC-1',
#  'AACATAGCATTGTTGG-1',
#  'AACATCATCGATTCTT-1',
#  'AACATTGTCCAGCACA-1',
#  'AACATTGTCCAGGTTG-1',
#  'AACATTGTCCCTCAGT-1',
#  'AACATTGTCGAAGTGA-1',
#  'AACCCGCAGGAGTAAT-1',
#  'AACCCGCAGTTTCCTG-1',
#  'AACCGCTCAAGGTGCA-1',
#  'AACCGCTCAGCAAGTG-1',
#  'AACCGCTCATGACTAT-1',
#  'AACCGCTCATGTCAGC-1',
#  'AACCGGCTCATTGACA-1',
#  'AACCGGCTCGTTATCT-1',
#  'AACCTAATCACTAGGT-1',
#  'AACCTAATCAGTGAAG-1',
#  'AACCTAATCCTCATGC-1',
#  'AACCTAATCGCTTCTA-1',
#  'AACCTAATCGTTAGTA-1',
#  'AACCTCACAACCTGGT-1',
#  'AACCTCACAGAGAGCC-1',
#  'AACCTCACAGTAGCCT-1',
#  'AACCTCCTCATAAGCC-1',
#  'AACCTCCTCATGCAAC-1',
#  'AACCTCCTCATGTTTC-1',
#  'AACCTCCTCCACCCTG-1',
#  'AACCTCCTCCCAGTAG-1',
#  'AACCTCCTCTAATCTC-1',
#  'AACCTCCTCTCACTAT-1',
#  'AACCTCCTCTTAAGTG-1',
#  'AACCTTAAGAGAGCCG-1',
#  'AACCTTAAGATACTTG-1',
#  'AACCTTAAGCAGGCCT-1',
#  'AACCTTAAGCATGGTT-1',
#  'AACCTTAAGCTATTAG-1',
#  'AACCTTAAGGGACTAA-1',
#  'AACCTTAAGTAAGTCC-1',
#  'AACCTTGCAGGGAGGA-1',
#  'AACCTTGCATAAACCT-1',
#  'AACGACAAGCCTGACA-1',
#  'AACGACAAGCTGGACC-1',
#  'AACGACAAGGCGCATC-1',
#  'AACGACAAGGTCCAAT-1',
#  'AACGACAAGTTGTCTT-1',
#  'AACGCCCAGAACCTAC-1',
#  'AACGCCCAGCTCAAAC-1',
#  'AACGCCCAGGGACCTC-1',
#  'AACGCCCAGGTCCGTA-1',
#  'AACGCTAGTCATTACC-1',
#  'AACGCTAGTGAGCACT-1',
#  'AACGCTAGTGTTAAAC-1',
#  'AACGCTAGTTACGCGG-1',
#  'AACGCTAGTTTGCGCC-1',
#  'AACGGTAAGAGGCTAA-1',
#  'AACGGTAAGATTGAGG-1',
#  'AACGGTAAGGATCCGC-1',
#  'AACGGTAAGGCTAAGA-1',
#  'AACGGTAAGGTATTGC-1',
#  'AACTACTCAAGCCACT-1',
#  'AACTACTCACCAAAGG-1',
#  'AACTACTCACCGGTAT-1',
#  'AACTACTCAGCACCAT-1',
#  'AACTACTCAGTAAAGC-1',
#  'AACTACTCATAATGTC-1',
#  'AACTAGCTCATGAAGG-1',
#  'AACTAGCTCCTGGTGA-1',
#  'AACTAGCTCCTTGCAC-1',
#  'AACTAGCTCGTTATCT-1',
#  'AACTAGCTCTAGCGAT-1',
#  'AACTAGTGTATTTGCC-1',
#  'AACTAGTGTCCTAACT-1',
#  'AACTAGTGTGTCCAGG-1',
#  'AACTAGTGTTAAATGC-1',
#  'AACTAGTGTTAGGATT-1',
#  'AACTAGTGTTGGATCA-1',
#  'AACTAGTGTTTCCGGC-1',
#  'AACTCACAGCCTAACG-1',
#  'AACTCACAGGCATTGT-1',
#  'AACTCACAGTTTGAGC-1',
#  'AACTGTTCACAATACT-1',
#  'AACTGTTCACCGTTCC-1',
#  'AACTGTTCACCTAAGC-1',
#  'AACTGTTCAGTCTAGC-1',
#  'AACTGTTCATGTCAGC-1',
#  'AACTTAGTCACTAAGC-1',
#  'AACTTAGTCATTGCGG-1',
#  'AACTTAGTCCCATAGG-1',
#  'AACTTAGTCCCGAAGC-1',
#  'AACTTAGTCCCGTTTA-1',
#  'AACTTAGTCGCTCCAT-1',
#  'AACTTAGTCGGCTATG-1',
#  'AACTTAGTCTGGCAAT-1',
#  'AAGAACAGTAACCACA-1',
#  'AAGAACAGTCATGCAA-1',
#  'AAGAACAGTCGCGCAA-1',
#  'AAGAACAGTCGTTACT-1',
#  'AAGAACAGTGCATTTC-1',
#  'AAGAACAGTGGACCTG-1',
#  'AAGAATCAGCCGCAGT-1',
#  'AAGAATCAGCTTTGTT-1',
#  'AAGAATCAGTAACTCA-1',
#  'AAGAATCAGTATTGTG-1',
#  'AAGAATCAGTCTCACC-1',
#  'AAGAATCAGTTATCCT-1',
#  'AAGACAAGTCAGGCCA-1',
#  'AAGACAAGTTACCTGT-1',
#  'AAGACAAGTTAGAGCC-1',
#  'AAGACATAGGGCTAAA-1',
#  'AAGACATAGGTAACGA-1',
#  'AAGACATAGTAACAGG-1',
#  'AAGACATAGTGTTGCG-1',
#  'AAGACATAGTTGGATC-1',
#  'AAGACCAAGAAAGCAT-1',
#  'AAGACCAAGACTTATG-1',
#  'AAGACCAAGCGATAGA-1',
#  'AAGACCAAGCTAATCA-1',
#  'AAGACCAAGGCTAATC-1',
#  'AAGACCAAGGTCCTAG-1',
#  'AAGCAAGTCAAACACC-1',
#  'AAGCAAGTCAAACCGT-1',
#  'AAGCAAGTCATTACAG-1',
#  'AAGCAAGTCCCAGTAG-1',
#  'AAGCAAGTCGATCAGT-1',
#  'AAGCAAGTCGCTAGCA-1',
#  'AAGCATGAGAGAGCCG-1',
#  'AAGCATGAGCAGGTTT-1',
#  'AAGCATGAGCGAGCGA-1',
#  'AAGCATGAGGATAAAC-1',
#  'AAGCATGAGGGCTTAT-1',
#  'AAGCATGAGTAAGTCC-1',
#  'AAGCATGAGTTGCCTC-1',
#  'AAGCCACGTGGTGAGA-1',
#  'AAGCCACGTTAGCTGA-1',
#  'AAGCCACGTTGGTTAG-1',
#  'AAGCCACGTTTATTCG-1',
#  'AAGCCTCCAAACCTAT-1',
#  'AAGCCTCCAAACCTTG-1',
#  'AAGCCTCCACAAACTT-1',
#  'AAGCCTCCACTTCACT-1',
#  'AAGCCTCCAGGAACAT-1',
#  'AAGCCTCCAGTACCGT-1',
#  'AAGCCTCCAGTTATGT-1',
#  'AAGCCTCCATCCATCT-1',
#  'AAGCCTGTCCAAGTGT-1',
#  'AAGCCTGTCCTAATAG-1',
#  'AAGCCTGTCGCCTAAG-1',
#  'AAGCCTGTCTCAATTC-1',
#  'AAGCCTGTCTCATCAT-1',
#  'AAGCCTGTCTGTGCAG-1',
#  'AAGCCTGTCTTAAGTG-1',
#  'AAGCCTTAGCATGCAT-1',
#  'AAGCCTTAGGAAGCAC-1',
#  'AAGCCTTAGGGTCTAT-1',
#  'AAGCCTTAGGTCCTAG-1',
#  'AAGCCTTAGTCATTGA-1',
#  'AAGCCTTAGTGAGCAA-1',
#  'AAGCCTTAGTTAGAGG-1',
#  'AAGCGAATCAGTATTG-1',
#  'AAGCGAATCGTCCTTA-1',
#  'AAGCGAATCGTTATCT-1',
#  'AAGCGAGGTACCAGGT-1',
#  'AAGCGAGGTACCCACC-1',
#  'AAGCGAGGTATTGAGT-1',
#  'AAGCGAGGTCGACTCC-1',
#  'AAGCGAGGTGGATTGC-1',
#  'AAGCGAGGTTAGCTGA-1',
#  'AAGCGAGGTTCACCAT-1',
#  'AAGCGCTGTGCCGCAA-1',
#  'AAGCGGGTCAGGTCCA-1',
#  'AAGCGGGTCTTAGGAC-1',
#  'AAGCGTTTCATTGTCT-1',
#  'AAGCGTTTCGAGGTGG-1',
#  'AAGCGTTTCGCACAAT-1',
#  'AAGCGTTTCTAACCAA-1',
#  'AAGCTAGAGCCTGAGC-1',
#  'AAGCTAGAGCTATTAG-1',
#  'AAGCTAGAGCTTAACA-1',
#  'AAGCTAGAGGACCGCT-1',
#  'AAGCTAGAGGAGCATA-1',
#  'AAGCTAGAGGCCTGGT-1',
#  'AAGCTAGAGTTAGACC-1',
#  'AAGCTATGTCTCACTG-1',
#  'AAGCTATGTGGGTACT-1',
#  'AAGCTATGTGTGCACG-1',
#  'AAGCTATGTTAGAGGG-1',
#  'AAGCTATGTTGGTGAC-1',
#  'AAGCTCCCACAAAGAC-1',
#  'AAGCTCCCACAGCCTG-1',
#  'AAGCTCCCATGGAGGC-1',
#  'AAGCTTGGTACCGTTT-1',
#  'AAGCTTGGTATTCGCT-1',
#  'AAGCTTGGTGAGCGAA-1',
#  'AAGCTTGGTTCCTGAT-1',
#  'AAGGAAGCAATTGACT-1',
#  'AAGGAAGCACATTGCA-1',
#  'AAGGAAGCATGAGTTT-1',
#  'AAGGATCCAACCCTAA-1',
#  'AAGGATCCAAGCTACC-1',
#  'AAGGATCCACGGTACT-1',
#  'AAGGATCCAGGCTAAG-1',
#  'AAGGATCCAGGGAGCT-1',
#  'AAGGATCCATAAAGCA-1',
#  'AAGGATCCATTAGCGC-1',
#  'AAGGATGTCAAGGACA-1',
#  'AAGGATGTCCCTCACG-1',
#  'AAGGATGTCGTTTCTG-1',
#  'AAGGATTAGAGAGGAG-1',
#  'AAGGATTAGCAAACCT-1',
#  'AAGGATTAGCCTGTGA-1',
#  'AAGGATTAGCTACTGG-1',
#  'AAGGATTAGTAACCAC-1',
#  'AAGGATTAGTAGGCGG-1',
#  'AAGGATTAGTTCCTCA-1',
#  'AAGGCCCTCACTAGGT-1',
#  'AAGGCCCTCATCAGTA-1',
#  'AAGGCCCTCATGCATA-1',
#  'AAGGCCCTCATTGCAA-1',
#  'AAGGCCCTCTTAGCCC-1',
#  'AAGGCCCTCTTGCTAT-1',
#  'AAGGTATAGGAGCAAC-1',
#  'AAGGTATAGGGCTAAA-1',
#  'AAGGTATAGTTAGGCT-1',
#  'AAGGTATAGTTGTCAA-1',
#  'AAGGTATAGTTTCCGC-1',
#  'AAGGTCAAGAGGCTAA-1',
#  'AAGGTCAAGCAAACCT-1',
#  'AAGGTCAAGCAACATC-1',
#  'AAGGTCAAGCCGCAAC-1',
#  'AAGGTCAAGGATTTGC-1',
#  'AAGGTCAAGGTAACGA-1',
#  'AAGGTCAAGTCATTAG-1',
#  'AAGGTGCAGCTAATTG-1',
#  'AAGGTGCAGGAACGCG-1',
#  'AAGGTGCAGGCCCAGT-1',
#  'AAGGTGCAGTAAGTGG-1',
#  'AAGGTGCAGTCTCACC-1',
#  'AAGGTGCAGTTATGGC-1',
#  'AAGTAGCCAAACCTAT-1',
#  'AAGTAGCCAAACTGTT-1',
#  'AAGTAGCCAACAGCCT-1',
#  'AAGTAGCCAAGCTAAA-1',
#  'AAGTAGCCACTAAGCC-1',
#  'AAGTAGCCATTAGCCA-1',
#  'AAGTCTATCCCGCAAA-1',
#  'AAGTCTATCTAACTGA-1',
#  'AAGTGAAGTCCTTCTC-1',
#  'AAGTGCAAGATACTTG-1',
#  'AAGTGCAAGCTTCCCG-1',
#  'AAGTGCAAGGCATGTT-1',
#  'AAGTGCAAGGCGAATA-1',
#  'AAGTGCAAGGTGAAGC-1',
#  'AAGTGCAAGTGAGCGG-1',
#  'AAGTGCAAGTTGTCCC-1',
#  'AAGTTACGTTCGCGCT-1',
#  'AAGTTACGTTGTGACA-1',
#  'AAGTTAGCAGCAAATA-1',
#  'AAGTTAGCAGCATGAG-1',
#  'AAGTTAGCAGCTACGT-1',
#  'AAGTTAGCAGGAACCA-1',
#  'AAGTTAGCAGTTATGT-1',
#  'AAGTTTGTCCCTCATA-1',
#  'AAGTTTGTCGCTCACT-1',
#  'AAGTTTGTCTTAGGGT-1',
#  'AATAACCGTGTCCAAA-1',
#  'AATACCGGTATCTGGA-1',
#  'AATACCGGTCCTAATC-1',
#  'AATAGAGGTATACTGG-1',
#  'AATAGAGGTCATCAAG-1',
#  'AATAGAGGTTAGCAGC-1',
#  'AATAGCTGTAAAGCGG-1',
#  'AATAGCTGTCATAACG-1',
#  'AATAGCTGTCATGAGC-1',
#  'AATAGCTGTCCTAACT-1',
#  'AATAGCTGTGAGAAAC-1',
#  'AATAGCTGTTGCTGGG-1',
#  'AATAGCTGTTTAACCC-1',
#  'AATATCCCACTTAGGC-1',
#  'AATATCCCAGCAAATA-1',
#  'AATATCCCAGCACGAA-1',
#  'AATCAGGAGCCAAATC-1',
#  'AATCAGGAGCTAATCA-1',
#  'AATCAGGAGCTCAATA-1',
#  'AATCAGGAGGCCGGAA-1',
#  'AATCAGGAGGCCTAAT-1',
#  'AATCAGGAGGCTACTG-1',
#  'AATCATCCAAGCCAGA-1',
#  'AATCATCCAGCCAGTT-1',
#  'AATCATCCAGGCCTTG-1',
#  'AATCATCCAGTTTCTC-1',
#  'AATCATCCATAGCTTG-1',
#  'AATCATGTCATGAAGG-1',
#  'AATCATGTCATGCGTG-1',
#  'AATCATGTCGTTTCGC-1',
#  'AATCATGTCTCGACCT-1',
#  'AATCATGTCTTAGCCC-1',
#  'AATCCATCAAATGCCC-1',
#  'AATCCATCAACCGCCA-1',
#  'AATCCATCAAGCTTAT-1',
#  'AATCCATCACATAACT-1',
#  'AATCCATCACGTGCTG-1',
#  'AATCCATCATCCCTCA-1',
#  'AATCCCTGTAACTACG-1',
#  'AATCCCTGTCCTTCTC-1',
#  'AATCCCTGTTTATTCG-1',
#  'AATCCGTAGAAAGCAT-1',
#  'AATCCGTAGACACCGC-1',
#  'AATCCGTAGATTCCTT-1',
#  'AATCCGTAGCAAGGTA-1',
#  'AATCCGTAGCAATAGG-1',
#  'AATCCGTAGCCGCAGT-1',
#  'AATCCGTAGGCCTTAG-1',
#  'AATCCGTAGTAAAGGT-1',
#  'AATCCGTAGTAATCCA-1',
#  'AATCCGTAGTCACCTC-1',
#  'AATCCGTAGTTATCCT-1',
#  'AATCCGTAGTTATGGC-1',
#  'AATCCTAAGACAAACG-1',
#  'AATCCTAAGACAAGTG-1',
#  'AATCCTAAGCATGTCG-1',
#  'AATCCTAAGCTCGCTT-1',
#  'AATCCTAAGGCATTAC-1',
#  'AATCCTAAGTTTGTCT-1',
#  'AATCGCCCAAACCTTG-1',
#  'AATCGCCCAATCATGT-1',
#  'AATCGCCCACAGGAAT-1',
#  'AATCGCCCACCACAAC-1',
#  'AATCGCCCAGAGAGCC-1',
#  'AATCGCCCATAGCTGC-1',
#  'AATCGCCCATAGGCGA-1',
#  'AATCGCCCATATAACC-1',
#  'AATCGCCCATCCTAGA-1',
#  'AATCGCCCATTGTCAG-1',
#  'AATCTCAAGCCACAAT-1',
#  'AATCTCAAGCCGCTAA-1',
#  'AATCTCAAGGCATTGT-1',
#  'AATCTCAAGTCAATTG-1',
#  'AATCTCAAGTGCACGC-1',
#  'AATCTCAAGTTAGACC-1',
#  'AATCTTGAGACAACAG-1',
#  'AATCTTGAGAGAGCCG-1',
#  'AATCTTGAGCAAACCT-1',
#  'AATCTTGAGCACTAAC-1',
#  'AATCTTGAGGAGGGTT-1',
#  'AATCTTGAGGTCCAAT-1',
#  'AATCTTGAGTCATGCG-1',
#  'AATGAAGGTTAACAGT-1',
#  'AATGAAGGTTTCCACG-1',
#  'AATGCAACAAACTCAT-1',
#  'AATGCAACAACTAGAA-1',
#  'AATGCAACAATCCCTT-1',
#  'AATGCAACACATGCTA-1',
#  'AATGCAACAGTTTGTG-1',
#  'AATGCATGTACGGTAC-1',
#  'AATGCATGTATTACCC-1',
#  'AATGCATGTGTGCAAC-1',
#  'AATGCATGTTGGGTTA-1',
#  'AATGCATGTTGTGACA-1',
#  'AATGCATGTTTGAGGC-1',
#  'AATGCATGTTTGTGGA-1',
#  'AATGCGCGTCCGTAGG-1',
#  'AATGCGCGTGCTAGCG-1',
#  'AATGCGCGTTGGCCGA-1',
#  'AATGGCGCAACTAGCC-1',
#  'AATGGCGCAGGCGATA-1',
#  'AATGTCATCCCTCAGT-1',
#  'AATGTCATCCTGTTCA-1',
#  'AATGTCATCGGCTAGC-1',
#  'AATGTCATCTCGACCT-1',
#  'AATGTCATCTGCAAAC-1',
#  'AATGTCCAGAAAGGAA-1',
#  'AATGTCCAGCTTAGCG-1',
#  'AATGTCCAGTAACCCG-1',
#  'AATGTCCAGTGTGATC-1',
#  'AATTACCCACCAGCAT-1',
#  'AATTACCCAGCCAGTT-1',
#  'AATTACCCAGCGCTTG-1',
#  'AATTAGCGTACTTAGG-1',
#  'AATTAGCGTCCTTCAG-1',
#  'AATTAGCGTGCTTAGA-1',
#  'AATTAGCGTGGTTCTT-1',
#  'AATTAGCGTTTACGTC-1',
#  'AATTAGGCACAATGCC-1',
#  'AATTAGGCACAGGAAT-1',
#  'AATTAGGCATCCCGCT-1',
#  'AATTCGTCAAACCCTA-1',
#  'AATTCGTCAAACTCAT-1',
#  'AATTCGTCAAGGAATC-1',
#  'AATTCGTCAAGGCCAA-1',
#  'AATTCGTCATTGCGTA-1',
#  'AATTGACGTGATGATT-1',
#  'AATTGCCAGCAACAAG-1',
#  'AATTGCCAGCTACTGG-1',
#  'AATTGCCAGCTCAAAC-1',
#  'AATTGCCAGGCTATGT-1',
#  'AATTGCCAGTCAATCA-1',
#  'AATTGCTCAAAGCGGC-1',
#  'AATTGGACAAACGCGA-1',
#  'AATTGGACACAACCTA-1',
#  'AATTGGACACAGACTC-1',
#  'AATTGGACAGCAACCT-1',
#  'AATTGGACAGTAAAGC-1',
#  'AATTGGACATCAGCAC-1',
#  'AATTGGGAGATAGACG-1',
#  'AATTGGGAGCCTTAAA-1',
#  'AATTGGGAGGAAGTAT-1',
#  'AATTGGGAGGAGTCGG-1',
#  'AATTGGGAGGGACGCA-1',
#  'AATTGTGTCAAACTCA-1',
#  'AATTGTGTCAAGACTC-1',
#  'AATTGTGTCGACAAAG-1',
#  'AATTGTGTCGCAATCG-1',
#  'AATTGTGTCTAGCTTT-1',
#  'AATTTCCTCAAGGACA-1',
#  'AATTTCCTCAATGACC-1',
#  'AATTTCCTCCATTACT-1',
#  'AATTTCCTCCCATAAA-1',
#  'AATTTCCTCCTCCTAA-1',
#  'AATTTGCCAAACGCGA-1',
#  'AATTTGCCAAAGCGCA-1',
#  'AATTTGCCAAGCTACC-1',
#  'AATTTGCCAATTAACC-1',
#  'AATTTGCCACCGGTAT-1',
#  'AATTTGCCAGTAATAG-1',
#  'AATTTGCCATAAGTTC-1',
#  'AATTTGCCATAATTGC-1',
#  'AATTTGCCATCAGTAT-1',
#  'AATTTGGTCATTTGCT-1',
#  'AATTTGGTCGCAGGCT-1',
#  'AATTTGGTCGTTTCGC-1',
#  'AATTTGGTCTGCAAAC-1',
#  'ACAAACTGTGCGCGTA-1',
#  'ACAAAGGTCCGCAACA-1',
#  'ACAAAGGTCCTAGTCC-1',
#  'ACAAAGGTCTTTGAGA-1',
#  'ACAACAACAAGTCGCT-1',
#  'ACAACAACACACAATT-1',
#  'ACAACACTCAGGGCCT-1',
#  'ACAACACTCCCTCATA-1',
#  'ACAACACTCGAAGTGA-1',
#  'ACAACACTCGGCCAGT-1',
#  'ACAACACTCGGGACTC-1',
#  'ACAACACTCTTGACCC-1',
#  'ACAACAGAGAAACTGG-1',
#  'ACAACAGAGCTCATAA-1',
#  'ACAACAGAGTCAGGCC-1',
#  'ACAACATGTGCTTAGA-1',
#  'ACAACATGTTCCGGCT-1',
#  'ACACAATGTGATGAGG-1',
#  'ACACCTTGTACCGTTT-1',
#  'ACACCTTGTCAAGTGC-1',
#  'ACACCTTGTCAGGCAT-1',
#  'ACACCTTGTCATCAAG-1',
#  'ACACCTTGTCTTGCTG-1',
#  'ACACCTTGTGTTAAAC-1',
#  'ACACGGACAAAGCGGC-1',
#  'ACACGGACAACATAAG-1',
#  'ACACGGACAATGCGCT-1',
#  'ACACGGACACACTAAT-1',
#  'ACACGGACACCTATAG-1',
#  'ACACGGACACCTGTAA-1',
#  'ACACTAATCATGACCG-1',
#  'ACACTAATCGCACAAT-1',
#  'ACACTAATCGGTCAAT-1',
#  'ACACTAGGTTGTCATC-1',
#  'ACACTTAAGCGCAATT-1',
#  'ACACTTGCACAGGAAT-1',
#  'ACACTTGCATTAGCCA-1',
#  'ACAGCCGGTAAAGCAA-1',
#  'ACAGCCGGTGGATTCA-1',
#  'ACAGCCGGTGTGAGAG-1',
#  'ACAGCCGGTTAGCGTA-1',
#  'ACAGCCGGTTGAGCCG-1',
#  'ACAGCGCTCCTTAGTT-1',
#  'ACAGCGCTCTAGCGAT-1',
#  'ACAGCGCTCTGTAATG-1',
#  'ACAGGAATCGTAATCA-1',
#  'ACAGGAATCTTGCTAT-1',
#  'ACAGGATCAAGTAAGC-1',
#  'ACAGGATCACAGCCTG-1',
#  'ACAGGATCACCAGGTT-1',
#  'ACAGGATCAGCACGAA-1',
#  'ACAGGATCATAGCTTG-1',
#  'ACAGGCTGTAACCTAG-1',
#  'ACAGGCTGTGAGGTGA-1',
#  'ACAGGCTGTGTCCTGC-1',
#  'ACAGGTAAGCTGAGGG-1',
#  'ACAGGTAAGGATAAAC-1',
#  'ACAGGTAAGGGACGCA-1',
#  'ACAGGTAAGGGACTAA-1',
#  'ACAGGTAAGTTGTCCC-1',
#  'ACAGTATGTCAGGCAT-1',
#  'ACAGTATGTCCAAGAC-1',
#  'ACATAGCTCATGAGCT-1',
#  'ACATAGCTCCCTGGAA-1',
#  'ACATAGCTCCCTGTTA-1',
#  'ACATAGCTCGATATTG-1',
#  'ACATAGCTCTGGCATG-1',
#  'ACATAGCTCTTAGGAC-1',
#  'ACATCAATCATAATCG-1',
#  'ACATCAATCCCGCATT-1',
#  'ACATCAATCCTTAAGA-1',
#  'ACATCAATCTGGTCCT-1',
#  'ACATCATCAAGTCGCT-1',
#  'ACATCATCAGCTCAAC-1',
#  'ACATCATCATTAAGCT-1',
#  'ACATTAGTCATCCTGC-1',
#  'ACATTAGTCCGTTAAA-1',
#  'ACATTAGTCGCGACAC-1',
#  'ACATTAGTCGCGCTAA-1',
#  'ACATTAGTCGCTTCTA-1',
#  'ACATTGCAGCGCTCAA-1',
#  'ACATTGCAGTAAGGGC-1',
#  'ACATTGCAGTCAGGCC-1',
#  'ACATTGCAGTTAGAGG-1',
#  'ACCAAACTCAATACGC-1',
#  'ACCAAACTCATGCTAA-1',
#  'ACCAAACTCCAAGTTA-1',
#  'ACCAAACTCGACCTGA-1',
#  'ACCAAGCGTTCCAGGG-1',
#  'ACCAAGTTCCGCCAAA-1',
#  'ACCAAGTTCGGTTTCC-1',
#  'ACCAATATCACCATTT-1',
#  'ACCAATATCACTAGGT-1',
#  'ACCAATATCAGTTCCC-1',
#  'ACCAATATCATGACCG-1',
#  'ACCAATATCTTGGACG-1',
#  'ACCACACCACACAATT-1',
#  'ACCACACCAGAGGCTA-1',
#  'ACCACACCAGCAGGTA-1',
#  'ACCACACCAGGCGATA-1',
#  'ACCACACCATAGCGGA-1',
#  'ACCACATAGCGAGCGA-1',
#  'ACCACATAGGACCTGC-1',
#  'ACCACATAGGCATGTT-1',
#  'ACCACATAGGCGCACT-1',
#  'ACCACATAGGCTACTG-1',
#  'ACCACATAGTAAGTCC-1',
#  'ACCAGCTCAATAATCC-1',
#  'ACCAGCTCAATCGCAC-1',
#  'ACCAGCTCAATTGAGA-1',
#  'ACCAGCTCACACTAAT-1',
#  'ACCAGCTCACTGACCG-1',
#  'ACCAGCTCAGCATGTC-1',
#  'ACCAGCTCAGGACCTT-1',
#  'ACCAGCTCATAGCGGA-1',
#  'ACCAGCTCATTGACAT-1',
#  'ACCAGGACACATACTG-1',
#  'ACCAGGACACCAGCAT-1',
#  'ACCAGGACACTGGCTG-1',
#  'ACCAGGACATAGACTT-1',
#  'ACCAGGCTCAAGTGAG-1',
#  'ACCAGGCTCCCGCAAA-1',
#  'ACCAGGCTCGATTCTT-1',
#  'ACCAGGGAGCGATACT-1',
#  'ACCAGGGAGCGCATTG-1',
#  'ACCAGGGAGGGCTTTG-1',
#  'ACCAGGGAGGTGTCCA-1',
#  'ACCAGGGAGTCACTAA-1',
#  'ACCATAATCAAACCTA-1',
#  'ACCATAATCCTAATTC-1',
#  'ACCATAATCGGTTTGG-1',
#  'ACCATTAAGCTAATTG-1',
#  'ACCATTAAGGCGCACT-1',
#  'ACCATTAAGGGCTTAT-1',
#  'ACCCAACCAAACCTAT-1',
#  'ACCCAACCAATTGCGC-1',
#  'ACCCAACCACAGCCTG-1',
#  'ACCCAACCAGACAAAC-1',
#  'ACCCAACCAGTAAGTA-1',
#  'ACCCAACCATCATGGC-1',
#  'ACCCAACCATTGTTGG-1',
#  'ACCCAGGGTAGGTTAT-1',
#  'ACCCAGGGTATGGTGC-1',
#  'ACCCAGGGTCAATACG-1',
#  'ACCCAGGGTCACGAAC-1',
#  'ACCCAGGGTGAACAAA-1',
#  'ACCCAGGGTGGAGCAA-1',
#  'ACCCGCTGTCACCTAT-1',
#  'ACCCGCTGTGATGATT-1',
#  'ACCCGCTGTGTTGCAA-1',
#  'ACCCGCTGTTCGCTTG-1',
#  'ACCCGCTGTTTGTGGA-1',
#  'ACCCGGTAGAAAGCAT-1',
#  'ACCCGGTAGGCTGGCT-1',
#  'ACCCGGTAGTCCTTCA-1',
#  'ACCCGGTAGTTATCTC-1',
#  'ACCCGGTAGTTATGGC-1',
#  'ACCCGTAAGAACCTAC-1',
#  'ACCCGTAAGCCGCTAA-1',
#  'ACCCGTAAGGAGGGTT-1',
#  'ACCCGTAAGGCTGGCT-1',
#  'ACCCTCCCAAAGCGGC-1',
#  'ACCCTCCCAGCAACCT-1',
#  'ACCCTGTTCATTGCAA-1',
#  'ACCCTGTTCCCTGGAA-1',
#  'ACCCTGTTCCGCTAGA-1',
#  'ACCCTGTTCGGCTAGC-1',
#  'ACCGAAGCACAGCCAT-1',
#  'ACCGAAGCACTGACCG-1',
#  'ACCGAAGCATATTGAC-1',
#  'ACCGAAGCATTAAGCT-1',
#  'ACCGAAGCATTGTTGG-1',
#  'ACCGCAATCACCAATA-1',
#  'ACCGCAATCACCGGTA-1',
#  'ACCGCAATCATGGTTA-1',
#  'ACCGCAATCTATGACA-1',
#  'ACCGGCTAGAATGACG-1',
#  'ACCGGCTAGCTGTACG-1',
#  'ACCGGCTAGGATTGAG-1',
#  'ACCGGCTAGGTGTTAC-1',
#  'ACCGGCTAGTCTCACC-1',
#  'ACCGGCTAGTGAACCT-1',
#  'ACCGGTTCAAGGACCA-1',
#  'ACCGGTTCATCCGTAA-1',
#  'ACCTAAATCAGGATGA-1',
#  'ACCTAAATCATCCTCA-1',
#  'ACCTAAATCCTTAGGG-1',
#  'ACCTAAATCCTTCTAG-1',
#  'ACCTAAATCGATTTGA-1',
#  'ACCTAAATCGCACAAT-1',
#  'ACCTAAATCGTTAACA-1',
#  'ACCTAAGGTTACCGGG-1',
#  'ACCTAAGGTTAGGTGC-1',
#  'ACCTAAGGTTGGTGAC-1',
#  'ACCTACCTCAATTGGC-1',
#  'ACCTACCTCCTGATTT-1',
#  'ACCTACCTCGCAACAT-1',
#  'ACCTACCTCGGTTTGG-1',
#  'ACCTCACTCAATCTAG-1',
#  'ACCTCACTCACGAATC-1',
#  'ACCTCACTCATGGTGT-1',
#  'ACCTCACTCGACAAAG-1',
#  'ACCTGGATCACTAAGC-1',
#  'ACCTGGATCATGCTAA-1',
#  'ACCTGGATCCCTGACT-1',
#  'ACCTGGATCCTTCTAG-1',
#  'ACCTGGATCCTTGCGT-1',
#  'ACCTGGATCTGTTGCC-1',
#  'ACCTGGTCAACAGGTG-1',
#  'ACCTGGTCAACTAACT-1',
#  'ACCTGGTCAGGCTTCG-1',
#  'ACCTGGTCAGTGAACG-1',
#  'ACCTGGTCATCATGGC-1',
#  'ACCTGTTGTAGGTTTG-1',
#  'ACCTGTTGTCACAGAC-1',
#  'ACCTGTTGTCATTACC-1',
#  'ACCTGTTGTGGATTCA-1',
#  'ACCTTCATCAGGAAGC-1',
#  'ACCTTCATCCGCAAAT-1',
#  'ACCTTCATCCTTGTTG-1',
#  'ACCTTCATCTGTGCAG-1',
#  'ACCTTCCAGACTTATG-1',
#  'ACCTTCCAGCAAGATG-1',
#  'ACCTTCCAGGCGGGTA-1',
#  'ACCTTGCTCAGGCCTA-1',
#  'ACCTTGCTCCAGGAAA-1',
#  'ACCTTGCTCGACCTGA-1',
#  'ACCTTGCTCGTCAAGT-1',
#  'ACCTTGTGTGGACATC-1',
#  'ACCTTGTGTTGAGGTC-1',
#  'ACCTTGTGTTGCGCGA-1',
#  'ACCTTGTGTTTGAGCA-1',
#  'ACGAACAAGCGCATTG-1',
#  'ACGAACAAGCTTATGA-1',
#  'ACGAACAAGGAACCGG-1',
#  'ACGAACAAGGCTTAAC-1',
#  'ACGAACAAGGTAACGA-1',
#  'ACGAACAAGGTTTGCG-1',
#  'ACGAACAAGTCTCACC-1',
#  'ACGAACAAGTTATCTC-1',
#  'ACGAAGTCAAGTTATC-1',
#  'ACGAAGTCACATGCTA-1',
#  'ACGAATCTCAGCATTA-1',
#  'ACGAATCTCATCCTCA-1',
#  'ACGAATCTCGCAACAT-1',
#  'ACGAATCTCGCAGGCT-1',
#  'ACGAATCTCTGTTGCC-1',
#  'ACGACAAAGCTTCTCA-1',
#  'ACGACAAAGCTTTGGG-1',
#  'ACGACAAAGGAATAAC-1',
#  'ACGACAAAGGATTGAG-1',
#  'ACGACAAAGGTGAAGC-1',
#  'ACGACAAAGTCACGAT-1',
#  'ACGACTTAGCTTAACA-1',
#  'ACGACTTAGGTGTTAC-1',
#  'ACGACTTAGGTTACAC-1',
#  'ACGAGTAAGACAACGA-1',
#  'ACGAGTAAGAGGATAT-1',
#  'ACGAGTAAGCTCAAAC-1',
#  'ACGAGTAAGCTGAGGG-1',
#  'ACGAGTAAGGCCGGAA-1',
#  'ACGAGTAAGTAGGCGG-1',
#  'ACGAGTAAGTCGCAAT-1',
#  'ACGAGTAAGTTGCGTG-1',
#  'ACGATTCAGCAGGTGG-1',
#  'ACGATTCAGCTTATGA-1',
#  'ACGATTCAGGAACGCG-1',
#  'ACGATTCAGGTAGCTT-1',
#  'ACGATTCAGGTGCGGA-1',
#  'ACGCAAGCAAACCTAT-1',
#  'ACGCAAGCAACTGGCT-1',
#  'ACGCAAGCAAGGTATA-1',
#  'ACGCAAGCAATACTGT-1',
#  'ACGCACGGTAGCCATA-1',
#  'ACGCACGGTCTTGCTG-1',
#  'ACGCACGGTGAGCAAG-1',
#  'ACGCACGGTGGTTATG-1',
#  'ACGCACGGTTAAGCCA-1',
#  'ACGCACGGTTCGCGCT-1',
#  'ACGCACGGTTTGACCT-1',
#  'ACGCACGGTTTGAGGC-1',
#  'ACGCCACAGCAGGTGG-1',
#  'ACGCCACAGCGCAATT-1',
#  'ACGCCACAGTTATGGC-1',
#  'ACGCCTAAGAGGCTAA-1',
#  'ACGCCTAAGCAAGGAC-1',
#  'ACGCCTAAGCCGGTAC-1',
#  'ACGCCTAAGCGAGCGA-1',
#  'ACGCCTAAGTAAACCC-1',
#  'ACGCCTAAGTAATCCA-1',
#  'ACGCCTAAGTTATCCT-1',
#  'ACGCCTTTCCAAGTGT-1',
#  'ACGCCTTTCGGGATTT-1',
#  'ACGCTTGAGAGGAGGA-1',
#  'ACGCTTGAGATAGACG-1',
#  'ACGCTTGAGCCTGACA-1',
#  'ACGCTTGAGGGATGCG-1',
#  'ACGCTTGAGTAAGTGG-1',
#  'ACGCTTGAGTGAGCGG-1',
#  'ACGCTTGAGTGTGATC-1',
#  'ACGGGAAGTAACCACA-1',
#  'ACGGGAAGTAAGGTCC-1',
#  'ACGGGAAGTCACCTAT-1',
#  'ACGGGAAGTGATCAGC-1',
#  'ACGGGAAGTTGTTCAC-1',
#  'ACGGTACGTATTTGGG-1',
#  'ACGGTACGTGTTGCTT-1',
#  'ACGGTACGTTAAGGCC-1',
#  'ACGGTACGTTTATTCG-1',
#  'ACGGTTAGTATTGGAT-1',
#  'ACGGTTAGTCCTTTAA-1',
#  'ACGGTTAGTGACATGC-1',
#  'ACGGTTAGTTACTTGC-1',
#  'ACGGTTAGTTCGCGCT-1',
#  'ACGGTTAGTTTACCGT-1',
#  'ACGGTTTAGCAGCTAT-1',
#  'ACGGTTTAGCGCATTG-1',
#  'ACGGTTTAGCTATTGA-1',
#  'ACGGTTTAGGAGTCGG-1',
#  'ACGGTTTAGGCTTAAC-1',
#  'ACGTACCCAAAGCGGC-1',
#  'ACGTACCCAATTGAAG-1',
#  'ACGTACCCACCTCACC-1',
#  'ACGTACCCAGCATGAG-1',
#  'ACGTACCCAGGCTAAG-1',
#  'ACGTCAAGTCCGTGAG-1',
#  'ACGTCAAGTCCTAACT-1',
#  'ACGTCAAGTCCTAATC-1',
#  'ACGTCAAGTCTAACCT-1',
#  'ACGTCAAGTGCATTTC-1',
#  'ACGTCAAGTTAACGAT-1',
#  'ACGTCAAGTTAGGCTA-1',
#  'ACGTCAAGTTTATCTG-1',
#  'ACGTCCAAGCAAACCT-1',
#  'ACGTCCAAGCACGTTG-1',
#  'ACGTCCAAGCGGGCAA-1',
#  'ACGTCCAAGCTATTAG-1',
#  'ACGTCCAAGCTGGACC-1',
#  'ACGTCCTTCCATAATG-1',
#  'ACGTCCTTCCTAAGTA-1',
#  'ACGTCCTTCGTAACGT-1',
#  'ACGTTACAGACTATTG-1',
#  'ACGTTACAGCAATAGG-1',
#  'ACGTTACAGGAGTCTT-1',
#  'ACGTTACAGGCGGGTA-1',
#  'ACGTTACAGGCTATGT-1',
#  'ACGTTACAGTTCCTCA-1',
#  'ACGTTACAGTTTGAGC-1',
#  'ACGTTGTAGCTGGACC-1',
#  'ACGTTGTAGGCGAATA-1',
#  'ACGTTGTAGGTCATTA-1',
#  'ACTAAAGCAACAACAA-1',
#  'ACTAAAGCACTTAACG-1',
#  'ACTAAAGCATCGCTTT-1',
#  'ACTAAAGCATTGACAT-1',
#  'ACTAACCAGCGATAAG-1',
#  'ACTAACCAGCTGGAAA-1',
#  'ACTAACCAGGCATGTT-1',
#  'ACTAACCAGGCTAGAA-1',
#  'ACTAACCAGGTGTCCA-1',
#  'ACTAACGGTTAGGACC-1',
#  'ACTAACTCAACTAGAA-1',
#  'ACTAACTCAAGGACCA-1',
#  'ACTAACTCACATACTG-1',
#  'ACTAACTCAGAGGGAG-1',
#  'ACTAACTCAGCCAGAA-1',
#  'ACTAACTCATAGACTT-1',
#  'ACTAATCCAAGCCACT-1',
#  'ACTAATCCAATTGAGA-1',
#  'ACTAGGCGTCACGGAT-1',
#  'ACTAGGCGTCATTAGG-1',
#  'ACTAGGCGTTGAAGCC-1',
#  'ACTAGGCGTTTAGTCC-1',
#  'ACTAGGCGTTTGCTGT-1',
#  'ACTATCCGTCTATCGT-1',
#  'ACTATCCGTGCTTTAC-1',
#  'ACTATCCGTTTATGGG-1',
#  'ACTATGTCAAGGTATA-1',
#  'ACTATGTCAATGCCCG-1',
#  'ACTATGTCACCTACTT-1',
#  'ACTATGTCACTTCACT-1',
#  'ACTATGTCAGGAAGCC-1',
#  'ACTATGTCAGGCCATT-1',
#  'ACTATGTCATCGCTTT-1',
#  'ACTCACCTCCCGCATT-1',
#  'ACTCACCTCCGCTAGA-1',
#  'ACTCACCTCGGTTTGG-1',
#  'ACTCACCTCGTTAGTA-1',
#  'ACTCACCTCTCAATGA-1',
#  'ACTCACCTCTCCTCTT-1',
#  'ACTCACTGTGACATGC-1',
#  'ACTCACTGTGCTGGTG-1',
#  'ACTCACTGTGTTGTAG-1',
#  'ACTCACTGTTGCTTCG-1',
#  'ACTCACTGTTTCGCGC-1',
#  'ACTCAGTAGAATGACG-1',
#  'ACTCAGTAGCCGCTTT-1',
#  'ACTCCTCAGCAAACCT-1',
#  'ACTCCTCAGGCAACAA-1',
#  'ACTCCTCAGGCGAATA-1',
#  'ACTCCTCAGGGTTATC-1',
#  'ACTCCTCAGTCACTCC-1',
#  'ACTCCTCAGTTTGGGT-1',
#  'ACTCGCGCAAACGCGA-1',
#  'ACTCGCGCACCCTCAC-1',
#  'ACTCGCGCACTAGCGT-1',
#  'ACTCGCGCAGTCTATG-1',
#  'ACTCGCTTCCTTGCGT-1',
#  'ACTCGCTTCGGGACCT-1',
#  'ACTCGCTTCGTGCCTT-1',
#  'ACTCGCTTCTGCAACG-1',
#  'ACTCGCTTCTTAATGG-1',
#  'ACTGAAACACCTCACC-1',
#  'ACTGAAACAGCCTGCA-1',
#  'ACTGAAACATATAACC-1',
#  'ACTGAATGTAAGGTTT-1',
#  'ACTGAATGTATTGGTG-1',
#  'ACTGAATGTGCTCACC-1',
#  'ACTGAATGTTAAGCCA-1',
#  'ACTGAATGTTCGCGCT-1',
#  'ACTGAATGTTGGTGAC-1',
#  'ACTGAATGTTTGGCGG-1',
#  'ACTTACAAGCAAGGGT-1',
#  'ACTTACAAGGTTAGAG-1',
#  'ACTTACAAGTCAGGCC-1',
#  'ACTTACAAGTGAGGGT-1',
#  'ACTTACTTCAAACACC-1',
#  'ACTTACTTCACGAATC-1',
#  'ACTTACTTCATCAGTA-1',
#  'ACTTACTTCCTAATAG-1',
#  'ACTTACTTCCTCAGCT-1',
#  'ACTTACTTCCTCATGC-1',
#  'ACTTACTTCTGTGAGT-1',
#  'ACTTAGGGTAAGCTCA-1',
#  'ACTTAGGGTCCCGGAA-1',
#  'ACTTAGGGTCCTTTAA-1',
#  'ACTTAGGGTGAACAAA-1',
#  'ACTTAGGGTTCCTCCT-1',
#  'ACTTAGGGTTGAGGTC-1',
#  'ACTTAGGGTTGTTGGA-1',
#  'ACTTAGTCACAATGTT-1',
#  'ACTTAGTCAGGCTAAG-1',
#  'ACTTAGTCAGTTAGCC-1',
#  'ACTTAGTCATAAAGCA-1',
#  'ACTTAGTCATCTAGCA-1',
#  'ACTTATCTCAAACACC-1',
#  'ACTTATCTCCTTGTTG-1',
#  'ACTTATCTCTGTGCAG-1',
#  'ACTTATCTCTTGCATT-1',
#  'ACTTATCTCTTTGACT-1',
#  'ACTTATGAGGAATAAC-1',
#  'ACTTATGAGTCTCACC-1',
#  'ACTTATGAGTGAGGGT-1',
#  'ACTTCGCTCCAGGTTG-1',
#  'ACTTCGCTCCGCACAA-1',
#  ...]

# %%
# Start from fragments file
adata = snap.pp.import_fragments(
    fragment_file=fragment_file,
    chrom_sizes=snap.genome.hg38,
    file=output_file,
    sorted_by_barcode=False,
    whitelist=whitelist,
    n_jobs=n_jobs,
)
adata
# Out:
# AnnData object with n_obs x n_vars = 8515 x 0 backed at 'results/1_qc_metrics/1619LM/1619LM.atac.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito'
#     uns: 'reference_sequences'
#     obsm: 'fragment_paired'

# %%
# Plot fragment size distribution
snap.pl.frag_size_distr(adata, interactive=False)
# Out:
# 2025-03-30 15:32:57 - INFO - Computing fragment size distribution...

# %%
# Compute TSSe scores of individual cells
snap.metrics.tsse(adata, snap.genome.hg38, n_jobs=n_jobs)
adata
# Out:
# AnnData object with n_obs x n_vars = 8515 x 0 backed at 'results/1_qc_metrics/1619LM/1619LM.atac.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#     uns: 'frag_size_distr', 'TSS_profile', 'reference_sequences', 'library_tsse', 'frac_overlap_TSS'
#     obsm: 'fragment_paired'

# %%
# Plot TSSe scores against number of unique fragments for each cell
snap.pl.tsse(adata, interactive=False)

# %%
# Create a cell by bin matrix
snap.pp.add_tile_matrix(adata, n_jobs=n_jobs)
adata
# Out:
# AnnData object with n_obs x n_vars = 8515 x 6062095 backed at 'results/1_qc_metrics/1619LM/1619LM.atac.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#     uns: 'frag_size_distr', 'TSS_profile', 'reference_sequences', 'library_tsse', 'frac_overlap_TSS'
#     obsm: 'fragment_paired'

# %%
# Select variable features (necessary for scrublet)
snap.pp.select_features(adata, blacklist=blacklist_file, n_jobs=n_jobs)
adata
# Out:
# 2025-03-30 15:33:41 - INFO - Selected 497412 features.
# AnnData object with n_obs x n_vars = 8515 x 6062095 backed at 'results/1_qc_metrics/1619LM/1619LM.atac.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#     var: 'count', 'selected'
#     uns: 'frag_size_distr', 'TSS_profile', 'reference_sequences', 'library_tsse', 'frac_overlap_TSS'
#     obsm: 'fragment_paired'

# %%
# Doublet detection
snap.pp.scrublet(adata, n_jobs=n_jobs)
adata
# Out:
# 2025-03-30 15:33:49 - INFO - Simulating doublets...
# 2025-03-30 15:33:50 - INFO - Spectral embedding ...
# 2025-03-30 15:35:04 - INFO - Calculating doublet scores...
# AnnData object with n_obs x n_vars = 8515 x 6062095 backed at 'results/1_qc_metrics/1619LM/1619LM.atac.h5ad'
#     obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse', 'doublet_probability', 'doublet_score'
#     var: 'count', 'selected'
#     uns: 'frag_size_distr', 'TSS_profile', 'reference_sequences', 'scrublet_sim_doublet_score', 'library_tsse', 'frac_overlap_TSS'
#     obsm: 'fragment_paired'

# %%
# Close object (saves to disk)
adata.close()
adata
# Out:
# Closed AnnData object
