# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys;sys.path.extend(['/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12/site-packages', '/home/brandon/code/pingyin/snmultiome/workflow/rules', '/home/brandon/code/pingyin/snmultiome/workflow', '/home/brandon/miniconda3/envs/snapatac2_env/bin', '/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12', '/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12/lib-dynload', '/home/brandon/miniconda3/envs/snapatac2_env/lib/python3.12/site-packages', '/home/brandon/.cache/snakemake/snakemake/source-cache/runtime-cache/tmp9ekb0ygo/file/home/brandon/code/pingyin/snmultiome/workflow/rules/../notebooks/3_analysis', '/home/brandon/code/pingyin/snmultiome/workflow/rules/../notebooks/3_analysis']);import pickle;from snakemake import script;script.snakemake = pickle.loads(b'\x80\x04\x95\xdc\x05\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94\x8c8results/2_filtering/1633MM-repeat/1633MM-repeat.rna.h5ad\x94a}\x94(\x8c\x06_names\x94}\x94\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x10h\x06\x8c\x0eAttributeGuard\x94\x93\x94)\x81\x94}\x94\x8c\x04name\x94h\x10sbh\x11h\x13)\x81\x94}\x94h\x16h\x11sbub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8c7results/3_analysis/1633MM-repeat/1633MM-repeat.rna.h5ad\x94a}\x94(h\x0c}\x94h\x0e]\x94(h\x10h\x11eh\x10h\x13)\x81\x94}\x94h\x16h\x10sbh\x11h\x13)\x81\x94}\x94h\x16h\x11sbub\x8c\r_params_store\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94\x8c\x1bHuman_Endometrium_Atlas.pkl\x94a}\x94(h\x0c}\x94\x8c\x10celltypist_model\x94K\x00N\x86\x94sh\x0e]\x94(h\x10h\x11eh\x10h\x13)\x81\x94}\x94h\x16h\x10sbh\x11h\x13)\x81\x94}\x94h\x16h\x11sbh,h)ub\x8c\r_params_types\x94}\x94\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\r1633MM-repeat\x94a}\x94(h\x0c}\x94\x8c\x06sample\x94K\x00N\x86\x94sh\x0e]\x94(h\x10h\x11eh\x10h\x13)\x81\x94}\x94h\x16h\x10sbh\x11h\x13)\x81\x94}\x94h\x16h\x11sb\x8c\x06sample\x94h9ub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x0c}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x0e]\x94(h\x10h\x11eh\x10h\x13)\x81\x94}\x94h\x16h\x10sbh\x11h\x13)\x81\x94}\x94h\x16h\x11sbhLK\x01hNK\x01hPhIub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c<logs/notebooks/3_analysis/1633MM-repeat/1-rna_analysis.ipynb\x94a}\x94(h\x0c}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x0e]\x94(h\x10h\x11eh\x10h\x13)\x81\x94}\x94h\x16h\x10sbh\x11h\x13)\x81\x94}\x94h\x16h\x11sbh^h[ub\x8c\x06config\x94}\x94(\x8c\x08data_dir\x94\x8c,/home/brandon/data/pingyin/snmultiome/input/\x94\x8c\x0bresults_dir\x94\x8c\x08results/\x94\x8c\x07samples\x94]\x94(\x8c\x061619LM\x94\x8c\x061619MM\x94\x8c\x061633LM\x94\x8c\r1633MM-repeat\x94e\x8c\x03RNA\x94}\x94(\x8c\x10celltypist_model\x94h)\x8c\nqc_filters\x94}\x94(\x8c\tmin_genes\x94K\xc8\x8c\rpct_counts_mt\x94K\x05\x8c\x0fpct_counts_ribo\x94K\x05\x8c\rdoublet_score\x94G?\xd3333333uu\x8c\x04ATAC\x94}\x94(\x8c\tblacklist\x94\x8c\x1fresources/hg38-blacklist.v2.bed\x94\x8c\nqc_filters\x94}\x94(\x8c\x08min_tsse\x94K\x05\x8c\nmin_counts\x94M\xe8\x03uuu\x8c\x04rule\x94\x8c\x0crna_analysis\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cL/home/brandon/code/pingyin/snmultiome/workflow/rules/../notebooks/3_analysis\x94ub.');del script;from snakemake.logging import logger;from snakemake.script import snakemake;import os; os.chdir(r'/home/brandon/code/pingyin/snmultiome');
######## snakemake preamble end #########

# %% [markdown]
# # RNA-seq analysis

# %%
# Load libraries
import scanpy as sc
import celltypist
from snakemake.script import snakemake

# %%
# Read input and output paths from Snakemake
input_file = snakemake.input[0]
output_file = snakemake.output[0]
celltypist_model = snakemake.params.celltypist_model

# %%
# Load the data
adata = sc.read(input_file)
adata
# Out:
# AnnData object with n_obs × n_vars = 6569 × 36601
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'pct_counts_hb', 'doublet_score', 'predicted_doublet', 'n_genes'
#     var: 'gene_ids', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'scrublet'

# %%
# Log-normalize the data
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.raw = adata
adata
# Out:
# AnnData object with n_obs × n_vars = 6569 × 36601
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'pct_counts_hb', 'doublet_score', 'predicted_doublet', 'n_genes'
#     var: 'gene_ids', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'scrublet', 'log1p'

# %%
# Feature selection
sc.pp.highly_variable_genes(adata)
sc.pl.highly_variable_genes(adata)

# %%
# Scale log-normalized counts to zero mean and unit variance
sc.pp.scale(adata, max_value=10)

# %%
# PCA
sc.tl.pca(adata, svd_solver="arpack")
sc.pl.pca_variance_ratio(adata, log=True)

# %%
# Neighbors
sc.pp.neighbors(adata)

# %%
# Nonlinear dimensionality reduction
sc.tl.umap(adata)
sc.pl.umap(adata, color=["pct_counts_mt", "doublet_score"])

# %%
# Clustering
sc.tl.leiden(adata)
sc.pl.umap(adata, color="leiden", legend_loc="on data")

# %%
# Celltypist for cell type annotation
predictions = celltypist.annotate(
    adata,
    model=celltypist_model,
    majority_voting=True,
    over_clustering="leiden",
)
celltypist.dotplot(
    predictions,
    use_as_reference="leiden",
    use_as_prediction="predicted_labels",
)
celltypist.dotplot(
    predictions,
    use_as_reference="leiden",
    use_as_prediction="majority_voting",
)
# Out:
# 👀 Invalid expression matrix in `.X`, expect log1p normalized expression to 10000 counts per cell; will use `.raw.X` instead
# 🔬 Input data has 6569 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 3736 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!

# %%
# Visualize cell types on UMAP
adata.obs["predicted_labels"] = predictions.predicted_labels["predicted_labels"]
adata.obs["majority_voting"] = predictions.predicted_labels["majority_voting"]
sc.pl.umap(adata, color="majority_voting", legend_loc="on data")

# %%
# Save the analyzed data
adata.write(output_file)
